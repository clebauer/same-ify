# %%
# ********** Import Statements ************************************************************ #
import sys
import spotipy
import spotipy.util as util

import pandas as pd
import json
import math

import matplotlib.pyplot as plt
import seaborn as sns


from sklearn import datasets, linear_model

pd.set_option('display.max_rows', 500)

# %%
# ********** Define Intro Values ************************************************************ #
# Loading in the client id and secret.
#client_info = json.load(open('/Users/cassielebauer/Documents/Projects/secret credentials/sameify_creds.json'))

# Spotify user IDs for testing: these are public information.
user_ids = {'Cassie':'1242091675',
            'Caity':'12166088827',
            'Ben':'yaojxcyh5tczzlln0ygm9sfla',
            'Alex':'12130992491',
            'Jason':'jason.albert'}

# %%
class Sameify:
    # Scopes for initialization; these are for the Spotify API
    redirect_uri = 'http://localhost:1410/'
    client_info = json.load(open('/Users/cassielebauer/Documents/Projects/secret credentials/sameify_creds.json'))
    scopes = ['user-read-recently-played',
              'user-top-read',
              'playlist-read-collaborative',
              'user-library-read',
              'playlist-read-private',
              'user-read-private',
              'playlist-modify-public']

    def __init__(self, user_id, read_only=True):
        # Declare valuesl
        self.id = user_id
        self.client_id = self.client_info['client_id']
        self.client_secret = self.client_info['client_secret']
        
        # Connect to Spotify
        self.sp = self.spotify_connect()
        
        # Pull relevant main values
        self.name = self.sp.user(self.id)['display_name']
        self.playlists = self.get_all_playlists()
        self.personal_playlists = self.get_personal_playlists(self.playlists)
        self.personal_tracks = self.get_all_playlist_tracks(self.personal_playlists[0:2])

    # Connects to Spotify
    def spotify_connect(self):
        token = util.prompt_for_user_token(self.id,
                                            self.scopes,
                                            self.client_id,
                                            self.client_secret,
                                            self.redirect_uri)

        sp = spotipy.Spotify(auth=token)
        return sp
    
    #def overstep_limit(self, item_id):

    def get_playlist_id(self, playlist_name):
        return self.playlists.loc[self.playlists['playlist_name'] == playlist_name,'playlist_id'].values[0]
    
    def get_playlist_name(self, playlist_id):
        return self.playlists.loc[self.playlists['playlist_id'] == playlist_id,'playlist_name'].values[0]
    
    def get_all_playlist_tracks(self, list_of_playlists):
        num_tracks = sum(list_of_playlists['num_tracks'])
        input_txt = f'This may load up to {num_tracks} songs, which will take approximately {num_tracks//9} seconds. Please type Y to continue'
        cont = input(input_txt)
        if cont.upper() == 'Y':
            tracks_df = pd.DataFrame()

            for ix in range(len(list_of_playlists)):
                plist_tracks = self.get_playlist_tracks(list_of_playlists.loc[ix,'playlist_id'])
                tracks_df = tracks_df.append(plist_tracks)
            return tracks_df
        else:
            pass
            
    def get_playlist_tracks(self, playlist_id):
        ret_df = pd.DataFrame()
        
        playlist = self.sp.user_playlist_tracks(self.id, playlist_id)
        playlist_name = self.get_playlist_name(playlist_id)
        tracks = playlist['items']
        
        while playlist['next']:
            playlist = self.sp.next(playlist)
            tracks.extend(playlist['items'])
            
        for track in tracks:
            x = track['track']
            data = {'playlist_id'  : playlist_id,
                    'playlist_name': playlist_name,
                    'track_name'   : x['name'],
                    'track_id'     : x['id'], 
                    'track_artist' : x['artists'][0]['name'], #[artist['name'] for artist in x['artists']]
                    'added_by'     : track['added_by']['id'],
                    'added_at'     : track['added_at']
                   }
            data_df = pd.DataFrame([data])
            song_deets = pd.DataFrame(self.sp.audio_features(data['track_id']))
            
            full_data = pd.concat([data_df, song_deets],axis=1)
            
            ret_df = ret_df.append(full_data)
        ret_df.reset_index(drop=True, inplace=True)
        return ret_df
            
        
    def get_all_playlists(self):
        playlists = pd.DataFrame()
        
        total = self.sp.user_playlists(self.id)['total'] #number of playlists
        limit = 50 # pull at a time
        
        for x in range(0, total, limit): # for each set of playlists
            new_playlist = self.sp.user_playlists(self.id, limit=limit, offset=x)
            for x in new_playlist['items']:
                items = {'playlist_name': x['name'],
                         'playlist_id'  : x['id'],
                         'owner_name'   : x['owner']['display_name'],
                         'owner_id'     : x['owner']['id'],
                         'num_tracks'   : x['tracks']['total'],
                         'collaborative': x['collaborative'],
                         }
                playlists = playlists.append(pd.DataFrame([items]))
        
        playlists.reset_index(drop=True, inplace=True)
        return playlists
     
    def remove_long_playlists(self, playlists):        
        req_text = '''The following playlists have over 100 tracks. Do you want to exclude any of these from the program? 
If so, please list the index numbers in a comma separated list. (e.g. "1,2,5,10").
For all playlists, please type "all".'''
        print(playlists[playlists['num_tracks']>=100][['playlist_name','num_tracks']])
        
        indices = input(req_text)
        if indices == 'all':
            print(playlists[['playlist_name','num_tracks']])
            req_text_2 = 'Please list the index numbers of the playlists to remove in a comma separated list. (e.g. "1,2,5,10")'
            indices = input(req_text_2)
        
        indices_to_exclude = [int(x) for x in indices.split(',')] if indices != '' else []

        indices_to_include = [x for x in playlists.index if x not in indices_to_exclude]
        playlists_to_use = playlists.iloc[indices_to_include,:].reset_index(drop=True)
        return playlists_to_use
    
    def get_personal_playlists(self, playlists):
        collab_filter = (playlists['collaborative'] == True) & (playlists['owner_name'] != self.name)
        personal_filter = playlists['owner_name'] == self.name
        personal_playlists = playlists[collab_filter | personal_filter].reset_index(drop=True)
        playlists_to_use = self.remove_long_playlists(personal_playlists)
        return playlists_to_use

# %%
# 1, 2, 3, 203, 204, 205, 206

# %%
cassie_acct = Sameify(user_ids['Cassie'],read_only=False)
# Out:
#                              playlist_name  num_tracks
# 9                         Recent old faves         101
# 12              All Songs (as of 01/11/22)        2268
# 14                 Discover Weekly Archive        1183
# 15                   Release Radar Archive         978
# 25                      The Nechromanticon         125
# 56                          Teenage Cassie         228
# 58   It's LIT! Essential HHM Playlist 2021         148
# 150                     Discovered & Loved         149
# 151                         Songs Saved v1         113
# 231               Release Radar Archive v1        4987
# 232             Discover Weekly Archive v2        4385
# 234                Discover Weekly Archive         502
# 235                  Release Radar Archive         505
# The following playlists have over 100 tracks. Do you want to exclude any of these from the program?
# If so, please list the index numbers in a comma separated list. (e.g. "1,2,5,10").
# For all playlists, please type "all".
# This may load up to 50 songs, which will take approximately 5 seconds. Please type Y to continuey

# %%
song_about_rain_dict = cassie_acct.sp.search('Song About Rain Judah S. Goldman')['tracks']['items'][0]

# %%
cassie_acct.sp.artist('0OcpF3dRDGb8cJneTvXlot')
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0OcpF3dRDGb8cJneTvXlot'},
#  'followers': {'href': None, 'total': 6},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/artists/0OcpF3dRDGb8cJneTvXlot',
#  'id': '0OcpF3dRDGb8cJneTvXlot',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273354977cd6b5fe61a21586361',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02354977cd6b5fe61a21586361',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851354977cd6b5fe61a21586361',
#    'width': 64}],
#  'name': 'José D. Cruz',
#  'popularity': 0,
#  'type': 'artist',
#  'uri': 'spotify:artist:0OcpF3dRDGb8cJneTvXlot'}

# %%
cassie_acct.sp.search("Jose D Cruz")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Jose+D+Cruz&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56TkPi7rpmU8jTpkcK7FY3'},
#        'href': 'https://api.spotify.com/v1/artists/56TkPi7rpmU8jTpkcK7FY3',
#        'id': '56TkPi7rpmU8jTpkcK7FY3',
#        'name': 'Beth Carvalho',
#        'type': 'artist',
#        'uri': 'spotify:artist:56TkPi7rpmU8jTpkcK7FY3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5SZ3V2KJ2TBfhez9Yz1PlW'},
#      'href': 'https://api.spotify.com/v1/albums/5SZ3V2KJ2TBfhez9Yz1PlW',
#      'id': '5SZ3V2KJ2TBfhez9Yz1PlW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735afc25c65119483e0bf5b36b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025afc25c65119483e0bf5b36b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515afc25c65119483e0bf5b36b',
#        'width': 64}],
#      'name': 'A madrinha do samba ao vivo convida',
#      'release_date': '2004-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5SZ3V2KJ2TBfhez9Yz1PlW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/56TkPi7rpmU8jTpkcK7FY3'},
#       'href': 'https://api.spotify.com/v1/artists/56TkPi7rpmU8jTpkcK7FY3',
#       'id': '56TkPi7rpmU8jTpkcK7FY3',
#       'name': 'Beth Carvalho',
#       'type': 'artist',
#       'uri': 'spotify:artist:56TkPi7rpmU8jTpkcK7FY3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2x5fdOl1kpBgD74cOkzNY0'},
#       'href': 'https://api.spotify.com/v1/artists/2x5fdOl1kpBgD74cOkzNY0',
#       'id': '2x5fdOl1kpBgD74cOkzNY0',
#       'name': 'Almir Guineto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2x5fdOl1kpBgD74cOkzNY0'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/096an3uS6ZaK2XySae6SqP'},
#       'href': 'https://api.spotify.com/v1/artists/096an3uS6ZaK2XySae6SqP',
#       'id': '096an3uS6ZaK2XySae6SqP',
#       'name': 'Arlindo Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:096an3uS6ZaK2XySae6SqP'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3qZ2n5keOAat1SoF6bHwmb'},
#       'href': 'https://api.spotify.com/v1/artists/3qZ2n5keOAat1SoF6bHwmb',
#       'id': '3qZ2n5keOAat1SoF6bHwmb',
#       'name': 'Zeca Pagodinho',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qZ2n5keOAat1SoF6bHwmb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5GmHrvfki94D20jsW5PRTi'},
#       'href': 'https://api.spotify.com/v1/artists/5GmHrvfki94D20jsW5PRTi',
#       'id': '5GmHrvfki94D20jsW5PRTi',
#       'name': 'Sombrinha',
#       'type': 'artist',
#       'uri': 'spotify:artist:5GmHrvfki94D20jsW5PRTi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 390226,
#     'explicit': False,
#     'external_ids': {'isrc': 'BRESM0400631'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1pg9n1Mv1wTND1g095dkSW'},
#     'href': 'https://api.spotify.com/v1/tracks/1pg9n1Mv1wTND1g095dkSW',
#     'id': '1pg9n1Mv1wTND1g095dkSW',
#     'is_local': False,
#     'name': 'Pot-Pourri: Camarão que dorme a onda leva / São José de Madureira / Dor de amor - Ao vivo',
#     'popularity': 18,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fef9fd22033a810714e2b9d6ae40cf24fbe243eb?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:1pg9n1Mv1wTND1g095dkSW'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Tz1WfJZkvWPhyFHWAzZLo'},
#      'href': 'https://api.spotify.com/v1/albums/1Tz1WfJZkvWPhyFHWAzZLo',
#      'id': '1Tz1WfJZkvWPhyFHWAzZLo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734e19f670ace532c6c2202094',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024e19f670ace532c6c2202094',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514e19f670ace532c6c2202094',
#        'width': 64}],
#      'name': 'El Ultimo Adiós',
#      'release_date': '2001-11-21',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:1Tz1WfJZkvWPhyFHWAzZLo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7slfeZO9LsJbWgpkIoXBUJ'},
#       'href': 'https://api.spotify.com/v1/artists/7slfeZO9LsJbWgpkIoXBUJ',
#       'id': '7slfeZO9LsJbWgpkIoXBUJ',
#       'name': 'Ricky Martin',
#       'type': 'artist',
#       'uri': 'spotify:artist:7slfeZO9LsJbWgpkIoXBUJ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5sUrlPAHlS9NEirDB8SEbF'},
#       'href': 'https://api.spotify.com/v1/artists/5sUrlPAHlS9NEirDB8SEbF',
#       'id': '5sUrlPAHlS9NEirDB8SEbF',
#       'name': 'Alejandro Sanz',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sUrlPAHlS9NEirDB8SEbF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/23wEWD21D4TPYiJugoXmYb'},
#       'href': 'https://api.spotify.com/v1/artists/23wEWD21D4TPYiJugoXmYb',
#       'id': '23wEWD21D4TPYiJugoXmYb',
#       'name': 'Thalia',
#       'type': 'artist',
#       'uri': 'spotify:artist:23wEWD21D4TPYiJugoXmYb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nlpTZci9O5W8RsNoNH559'},
#       'href': 'https://api.spotify.com/v1/artists/3nlpTZci9O5W8RsNoNH559',
#       'id': '3nlpTZci9O5W8RsNoNH559',
#       'name': 'Juan Luis Guerra 4.40',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nlpTZci9O5W8RsNoNH559'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5IFCkqu9J6xdWeYMk5I889'},
#       'href': 'https://api.spotify.com/v1/artists/5IFCkqu9J6xdWeYMk5I889',
#       'id': '5IFCkqu9J6xdWeYMk5I889',
#       'name': 'Gloria Estefan',
#       'type': 'artist',
#       'uri': 'spotify:artist:5IFCkqu9J6xdWeYMk5I889'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2weA6hhVqTIN2gSn9PUB9U'},
#       'href': 'https://api.spotify.com/v1/artists/2weA6hhVqTIN2gSn9PUB9U',
#       'id': '2weA6hhVqTIN2gSn9PUB9U',
#       'name': 'Celia Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:2weA6hhVqTIN2gSn9PUB9U'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4pv1Jo4PbYI8LMADJoTWjE'},
#       'href': 'https://api.spotify.com/v1/artists/4pv1Jo4PbYI8LMADJoTWjE',
#       'id': '4pv1Jo4PbYI8LMADJoTWjE',
#       'name': 'Olga Tañón',
#       'type': 'artist',
#       'uri': 'spotify:artist:4pv1Jo4PbYI8LMADJoTWjE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4uoz4FUMvpeyGClFTTDBsD'},
#       'href': 'https://api.spotify.com/v1/artists/4uoz4FUMvpeyGClFTTDBsD',
#       'id': '4uoz4FUMvpeyGClFTTDBsD',
#       'name': 'Ricardo Montaner',
#       'type': 'artist',
#       'uri': 'spotify:artist:4uoz4FUMvpeyGClFTTDBsD'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/41ESHLayJ5sDKjAOv6cMhe'},
#       'href': 'https://api.spotify.com/v1/artists/41ESHLayJ5sDKjAOv6cMhe',
#       'id': '41ESHLayJ5sDKjAOv6cMhe',
#       'name': 'Ana Gabriel',
#       'type': 'artist',
#       'uri': 'spotify:artist:41ESHLayJ5sDKjAOv6cMhe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5O2KyWcHYBmjmobgNLumcb'},
#       'href': 'https://api.spotify.com/v1/artists/5O2KyWcHYBmjmobgNLumcb',
#       'id': '5O2KyWcHYBmjmobgNLumcb',
#       'name': 'Jorge Hernández',
#       'type': 'artist',
#       'uri': 'spotify:artist:5O2KyWcHYBmjmobgNLumcb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hYtANQYrE6pd2PbtEyTIy'},
#       'href': 'https://api.spotify.com/v1/artists/3hYtANQYrE6pd2PbtEyTIy',
#       'id': '3hYtANQYrE6pd2PbtEyTIy',
#       'name': 'Los Tigres Del Norte',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hYtANQYrE6pd2PbtEyTIy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Hf2g14O2TP25JUNZuvIgn'},
#       'href': 'https://api.spotify.com/v1/artists/6Hf2g14O2TP25JUNZuvIgn',
#       'id': '6Hf2g14O2TP25JUNZuvIgn',
#       'name': 'Alicia Villarreal',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Hf2g14O2TP25JUNZuvIgn'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6sq1yF0OZEWA4xoXVKW1L9'},
#       'href': 'https://api.spotify.com/v1/artists/6sq1yF0OZEWA4xoXVKW1L9',
#       'id': '6sq1yF0OZEWA4xoXVKW1L9',
#       'name': 'Alejandro Fernández',
#       'type': 'artist',
#       'uri': 'spotify:artist:6sq1yF0OZEWA4xoXVKW1L9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4vhNDa5ycK0ST968ek7kRr'},
#       'href': 'https://api.spotify.com/v1/artists/4vhNDa5ycK0ST968ek7kRr',
#       'id': '4vhNDa5ycK0ST968ek7kRr',
#       'name': 'Carlos Vives',
#       'type': 'artist',
#       'uri': 'spotify:artist:4vhNDa5ycK0ST968ek7kRr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7MbmKsnvXjl4GA7Dr27kko'},
#       'href': 'https://api.spotify.com/v1/artists/7MbmKsnvXjl4GA7Dr27kko',
#       'id': '7MbmKsnvXjl4GA7Dr27kko',
#       'name': 'Jaci Velasquez',
#       'type': 'artist',
#       'uri': 'spotify:artist:7MbmKsnvXjl4GA7Dr27kko'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3tJnB0s6c3oXPq1SCCavnd'},
#       'href': 'https://api.spotify.com/v1/artists/3tJnB0s6c3oXPq1SCCavnd',
#       'id': '3tJnB0s6c3oXPq1SCCavnd',
#       'name': 'Marco Antonio Solís',
#       'type': 'artist',
#       'uri': 'spotify:artist:3tJnB0s6c3oXPq1SCCavnd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4mN0qcMxWX8oToqfDPM5yV'},
#       'href': 'https://api.spotify.com/v1/artists/4mN0qcMxWX8oToqfDPM5yV',
#       'id': '4mN0qcMxWX8oToqfDPM5yV',
#       'name': 'José José',
#       'type': 'artist',
#       'uri': 'spotify:artist:4mN0qcMxWX8oToqfDPM5yV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4MbmeIi7C8qe1LboVhdaUN'},
#       'href': 'https://api.spotify.com/v1/artists/4MbmeIi7C8qe1LboVhdaUN',
#       'id': '4MbmeIi7C8qe1LboVhdaUN',
#       'name': 'Lucía Méndez',
#       'type': 'artist',
#       'uri': 'spotify:artist:4MbmeIi7C8qe1LboVhdaUN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2DlGxzQSjYe5N6G9nkYghR'},
#       'href': 'https://api.spotify.com/v1/artists/2DlGxzQSjYe5N6G9nkYghR',
#       'id': '2DlGxzQSjYe5N6G9nkYghR',
#       'name': 'Jennifer Lopez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2DlGxzQSjYe5N6G9nkYghR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7HBONupvCpvcMp1ZxK84Ii'},
#       'href': 'https://api.spotify.com/v1/artists/7HBONupvCpvcMp1ZxK84Ii',
#       'id': '7HBONupvCpvcMp1ZxK84Ii',
#       'name': 'Emmanuele',
#       'type': 'artist',
#       'uri': 'spotify:artist:7HBONupvCpvcMp1ZxK84Ii'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JbemQ1fPt2YmSLjAFhPBv'},
#       'href': 'https://api.spotify.com/v1/artists/1JbemQ1fPt2YmSLjAFhPBv',
#       'id': '1JbemQ1fPt2YmSLjAFhPBv',
#       'name': 'Chayanne',
#       'type': 'artist',
#       'uri': 'spotify:artist:1JbemQ1fPt2YmSLjAFhPBv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/27vNK840zYq6IfDijHPsv1'},
#       'href': 'https://api.spotify.com/v1/artists/27vNK840zYq6IfDijHPsv1',
#       'id': '27vNK840zYq6IfDijHPsv1',
#       'name': 'Gilberto Santa Rosa',
#       'type': 'artist',
#       'uri': 'spotify:artist:27vNK840zYq6IfDijHPsv1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1d6dwipPrsFSJVmFTTdFSS'},
#       'href': 'https://api.spotify.com/v1/artists/1d6dwipPrsFSJVmFTTdFSS',
#       'id': '1d6dwipPrsFSJVmFTTdFSS',
#       'name': 'Paulina Rubio',
#       'type': 'artist',
#       'uri': 'spotify:artist:1d6dwipPrsFSJVmFTTdFSS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/20VNXin5fi626FsmioiExE'},
#       'href': 'https://api.spotify.com/v1/artists/20VNXin5fi626FsmioiExE',
#       'id': '20VNXin5fi626FsmioiExE',
#       'name': 'Alberto "Beto" Zapata',
#       'type': 'artist',
#       'uri': 'spotify:artist:20VNXin5fi626FsmioiExE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZVoRDO29AlDXiMkRLMZSK'},
#       'href': 'https://api.spotify.com/v1/artists/1ZVoRDO29AlDXiMkRLMZSK',
#       'id': '1ZVoRDO29AlDXiMkRLMZSK',
#       'name': 'La Ley',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZVoRDO29AlDXiMkRLMZSK'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/43qxAkuKFB6fMNSeS5dO7Z'},
#       'href': 'https://api.spotify.com/v1/artists/43qxAkuKFB6fMNSeS5dO7Z',
#       'id': '43qxAkuKFB6fMNSeS5dO7Z',
#       'name': 'Ana Bárbara',
#       'type': 'artist',
#       'uri': 'spotify:artist:43qxAkuKFB6fMNSeS5dO7Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ff5IojFqry4841QjwULTV'},
#       'href': 'https://api.spotify.com/v1/artists/4ff5IojFqry4841QjwULTV',
#       'id': '4ff5IojFqry4841QjwULTV',
#       'name': 'Carlos Ponce',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ff5IojFqry4841QjwULTV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/10n1KB2sjTrGdyuC83y8jW'},
#       'href': 'https://api.spotify.com/v1/artists/10n1KB2sjTrGdyuC83y8jW',
#       'id': '10n1KB2sjTrGdyuC83y8jW',
#       'name': 'Jon Secada',
#       'type': 'artist',
#       'uri': 'spotify:artist:10n1KB2sjTrGdyuC83y8jW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2gDqGAadPIPiA7LtmNn74g'},
#       'href': 'https://api.spotify.com/v1/artists/2gDqGAadPIPiA7LtmNn74g',
#       'id': '2gDqGAadPIPiA7LtmNn74g',
#       'name': 'Gian Marco',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gDqGAadPIPiA7LtmNn74g'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8Sr092TqfHkfAA5fXXqG'},
#       'href': 'https://api.spotify.com/v1/artists/4V8Sr092TqfHkfAA5fXXqG',
#       'id': '4V8Sr092TqfHkfAA5fXXqG',
#       'name': 'Luis Fonsi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8Sr092TqfHkfAA5fXXqG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4OgNARLQSC4yy7Dsa5cqxx'},
#       'href': 'https://api.spotify.com/v1/artists/4OgNARLQSC4yy7Dsa5cqxx',
#       'id': '4OgNARLQSC4yy7Dsa5cqxx',
#       'name': 'Yuri',
#       'type': 'artist',
#       'uri': 'spotify:artist:4OgNARLQSC4yy7Dsa5cqxx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7mWCSSOYqm4E9mB7V4ot6S'},
#       'href': 'https://api.spotify.com/v1/artists/7mWCSSOYqm4E9mB7V4ot6S',
#       'id': '7mWCSSOYqm4E9mB7V4ot6S',
#       'name': 'Miguel Bosé',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mWCSSOYqm4E9mB7V4ot6S'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Awnuu794580X3uHQGx78O'},
#       'href': 'https://api.spotify.com/v1/artists/5Awnuu794580X3uHQGx78O',
#       'id': '5Awnuu794580X3uHQGx78O',
#       'name': 'Wilkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Awnuu794580X3uHQGx78O'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gr23KYBk2FyIBx5xpHVjE'},
#       'href': 'https://api.spotify.com/v1/artists/5gr23KYBk2FyIBx5xpHVjE',
#       'id': '5gr23KYBk2FyIBx5xpHVjE',
#       'name': 'Giselle',
#       'type': 'artist',
#       'uri': 'spotify:artist:5gr23KYBk2FyIBx5xpHVjE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5oj50e6WeS3yFv92YDOfXA'},
#       'href': 'https://api.spotify.com/v1/artists/5oj50e6WeS3yFv92YDOfXA',
#       'id': '5oj50e6WeS3yFv92YDOfXA',
#       'name': 'Melina Leon',
#       'type': 'artist',
#       'uri': 'spotify:artist:5oj50e6WeS3yFv92YDOfXA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5j8Q0VC4Be4yhcQ1tf8Sh7'},
#       'href': 'https://api.spotify.com/v1/artists/5j8Q0VC4Be4yhcQ1tf8Sh7',
#       'id': '5j8Q0VC4Be4yhcQ1tf8Sh7',
#       'name': 'Limi-T 21',
#       'type': 'artist',
#       'uri': 'spotify:artist:5j8Q0VC4Be4yhcQ1tf8Sh7'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#       'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#       'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#       'name': 'Christina Aguilera',
#       'type': 'artist',
#       'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7K78lVZ8XzkjfRSI7570FF'},
#       'href': 'https://api.spotify.com/v1/artists/7K78lVZ8XzkjfRSI7570FF',
#       'id': '7K78lVZ8XzkjfRSI7570FF',
#       'name': 'José Feliciano',
#       'type': 'artist',
#       'uri': 'spotify:artist:7K78lVZ8XzkjfRSI7570FF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/15YnmlNukYCFvwaFnoDwwV'},
#       'href': 'https://api.spotify.com/v1/artists/15YnmlNukYCFvwaFnoDwwV',
#       'id': '15YnmlNukYCFvwaFnoDwwV',
#       'name': 'José Luis Rodríguez',
#       'type': 'artist',
#       'uri': 'spotify:artist:15YnmlNukYCFvwaFnoDwwV'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 237466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10112826'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tzixmHNQfE6S6SirSToxW'},
#     'href': 'https://api.spotify.com/v1/tracks/0tzixmHNQfE6S6SirSToxW',
#     'id': '0tzixmHNQfE6S6SirSToxW',
#     'is_local': False,
#     'name': 'El Ultimo Adiós - Varios Artistas Version',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c810013a25333bb91c3d3e7cd22960fb800f990d?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0tzixmHNQfE6S6SirSToxW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ds6VsUgSpysVJeAUyLzYz'},
#        'href': 'https://api.spotify.com/v1/artists/0ds6VsUgSpysVJeAUyLzYz',
#        'id': '0ds6VsUgSpysVJeAUyLzYz',
#        'name': 'Real De Catorce',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ds6VsUgSpysVJeAUyLzYz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2PNsNhG7NDqA1bbx8hLe8S'},
#      'href': 'https://api.spotify.com/v1/albums/2PNsNhG7NDqA1bbx8hLe8S',
#      'id': '2PNsNhG7NDqA1bbx8hLe8S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad642a378b023867c98f342f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad642a378b023867c98f342f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad642a378b023867c98f342f',
#        'width': 64}],
#      'name': 'Recopilación: Canciones Emblemáticas Seleccionadas por el Autor José Cruz',
#      'release_date': '2012-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:2PNsNhG7NDqA1bbx8hLe8S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69Avenm82ghaDvtRCiSeJS'},
#       'href': 'https://api.spotify.com/v1/artists/69Avenm82ghaDvtRCiSeJS',
#       'id': '69Avenm82ghaDvtRCiSeJS',
#       'name': 'José Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:69Avenm82ghaDvtRCiSeJS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 179266,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF601200454'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7BpHx4p5DWdPNB3sY3WPFr'},
#     'href': 'https://api.spotify.com/v1/tracks/7BpHx4p5DWdPNB3sY3WPFr',
#     'id': '7BpHx4p5DWdPNB3sY3WPFr',
#     'is_local': False,
#     'name': 'Me Miraba a los Ojos',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a6d008c4730c2909b866c56dbec16c18688fcfb4?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7BpHx4p5DWdPNB3sY3WPFr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#        'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#        'id': '2T06whb4s6UiufL1j5Qtz9',
#        'name': 'José Alfredo Jimenez',
#        'type': 'artist',
#        'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4VTjV9cmHGY0hBLFIWQQY3'},
#      'href': 'https://api.spotify.com/v1/albums/4VTjV9cmHGY0hBLFIWQQY3',
#      'id': '4VTjV9cmHGY0hBLFIWQQY3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f70d87a334142f9c8453209d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f70d87a334142f9c8453209d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f70d87a334142f9c8453209d',
#        'width': 64}],
#      'name': 'Canta Sus Exitos Con La Banda Sinaloense El Recodo De Cruz Lizarraga (with Banda El Recodo De Don Cruz Lizarraga)',
#      'release_date': '1984',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4VTjV9cmHGY0hBLFIWQQY3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#       'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#       'id': '2T06whb4s6UiufL1j5Qtz9',
#       'name': 'José Alfredo Jimenez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 156960,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF016800086'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1y9yrdjt1wjKlD2UHrnUVj'},
#     'href': 'https://api.spotify.com/v1/tracks/1y9yrdjt1wjKlD2UHrnUVj',
#     'id': '1y9yrdjt1wjKlD2UHrnUVj',
#     'is_local': False,
#     'name': 'El Perro Negro',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2e65d476e5c89717482936de0e741f264c98b7c8?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:1y9yrdjt1wjKlD2UHrnUVj'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ds6VsUgSpysVJeAUyLzYz'},
#        'href': 'https://api.spotify.com/v1/artists/0ds6VsUgSpysVJeAUyLzYz',
#        'id': '0ds6VsUgSpysVJeAUyLzYz',
#        'name': 'Real De Catorce',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ds6VsUgSpysVJeAUyLzYz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2PNsNhG7NDqA1bbx8hLe8S'},
#      'href': 'https://api.spotify.com/v1/albums/2PNsNhG7NDqA1bbx8hLe8S',
#      'id': '2PNsNhG7NDqA1bbx8hLe8S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad642a378b023867c98f342f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad642a378b023867c98f342f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad642a378b023867c98f342f',
#        'width': 64}],
#      'name': 'Recopilación: Canciones Emblemáticas Seleccionadas por el Autor José Cruz',
#      'release_date': '2012-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:2PNsNhG7NDqA1bbx8hLe8S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69Avenm82ghaDvtRCiSeJS'},
#       'href': 'https://api.spotify.com/v1/artists/69Avenm82ghaDvtRCiSeJS',
#       'id': '69Avenm82ghaDvtRCiSeJS',
#       'name': 'José Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:69Avenm82ghaDvtRCiSeJS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 197573,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF601200461'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/58HoucBzRUWKOU6szpWgQN'},
#     'href': 'https://api.spotify.com/v1/tracks/58HoucBzRUWKOU6szpWgQN',
#     'id': '58HoucBzRUWKOU6szpWgQN',
#     'is_local': False,
#     'name': 'Llévate la Historia',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/312672b750423502cd51e940ed6e0deb4afdd050?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:58HoucBzRUWKOU6szpWgQN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#        'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#        'id': '2T06whb4s6UiufL1j5Qtz9',
#        'name': 'José Alfredo Jimenez',
#        'type': 'artist',
#        'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
# ...
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#       'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#       'id': '2T06whb4s6UiufL1j5Qtz9',
#       'name': 'José Alfredo Jimenez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 150400,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF016800083'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2z79qCDpc8W5V3WaG3LOHC'},
#     'href': 'https://api.spotify.com/v1/tracks/2z79qCDpc8W5V3WaG3LOHC',
#     'id': '2z79qCDpc8W5V3WaG3LOHC',
#     'is_local': False,
#     'name': 'Cuatro Caminos',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bad6ab22825382336c85d49e91ab2a6acd919ab9?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2z79qCDpc8W5V3WaG3LOHC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ds6VsUgSpysVJeAUyLzYz'},
#        'href': 'https://api.spotify.com/v1/artists/0ds6VsUgSpysVJeAUyLzYz',
#        'id': '0ds6VsUgSpysVJeAUyLzYz',
#        'name': 'Real De Catorce',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ds6VsUgSpysVJeAUyLzYz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2PNsNhG7NDqA1bbx8hLe8S'},
#      'href': 'https://api.spotify.com/v1/albums/2PNsNhG7NDqA1bbx8hLe8S',
#      'id': '2PNsNhG7NDqA1bbx8hLe8S',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ad642a378b023867c98f342f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ad642a378b023867c98f342f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ad642a378b023867c98f342f',
#        'width': 64}],
#      'name': 'Recopilación: Canciones Emblemáticas Seleccionadas por el Autor José Cruz',
#      'release_date': '2012-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:2PNsNhG7NDqA1bbx8hLe8S'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69Avenm82ghaDvtRCiSeJS'},
#       'href': 'https://api.spotify.com/v1/artists/69Avenm82ghaDvtRCiSeJS',
#       'id': '69Avenm82ghaDvtRCiSeJS',
#       'name': 'José Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:69Avenm82ghaDvtRCiSeJS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 2,
#     'duration_ms': 354466,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF601200468'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1tDSKHcjj0NYwW1N1BFKj7'},
#     'href': 'https://api.spotify.com/v1/tracks/1tDSKHcjj0NYwW1N1BFKj7',
#     'id': '1tDSKHcjj0NYwW1N1BFKj7',
#     'is_local': False,
#     'name': 'Blues del Atajo - Live Version',
#     'popularity': 10,
#     'preview_url': 'https://p.scdn.co/mp3-preview/aae3d13e2cb959572ee751ca86ee7eca4f81e6ae?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1tDSKHcjj0NYwW1N1BFKj7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#        'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#        'id': '2T06whb4s6UiufL1j5Qtz9',
#        'name': 'José Alfredo Jimenez',
#        'type': 'artist',
#        'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4VTjV9cmHGY0hBLFIWQQY3'},
#      'href': 'https://api.spotify.com/v1/albums/4VTjV9cmHGY0hBLFIWQQY3',
#      'id': '4VTjV9cmHGY0hBLFIWQQY3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f70d87a334142f9c8453209d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f70d87a334142f9c8453209d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f70d87a334142f9c8453209d',
#        'width': 64}],
#      'name': 'Canta Sus Exitos Con La Banda Sinaloense El Recodo De Cruz Lizarraga (with Banda El Recodo De Don Cruz Lizarraga)',
#      'release_date': '1984',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4VTjV9cmHGY0hBLFIWQQY3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2T06whb4s6UiufL1j5Qtz9'},
#       'href': 'https://api.spotify.com/v1/artists/2T06whb4s6UiufL1j5Qtz9',
#       'id': '2T06whb4s6UiufL1j5Qtz9',
#       'name': 'José Alfredo Jimenez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2T06whb4s6UiufL1j5Qtz9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 124360,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF019100540'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0bDIO27o7M2OLsUplV3vw9'},
#     'href': 'https://api.spotify.com/v1/tracks/0bDIO27o7M2OLsUplV3vw9',
#     'id': '0bDIO27o7M2OLsUplV3vw9',
#     'is_local': False,
#     'name': 'La Que Se Fue',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df5f2847b1dbe9379bbb35df2682804695282d5e?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:0bDIO27o7M2OLsUplV3vw9'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Jose+D+Cruz&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 932}}

# %%
cassie_acct.sp.current_user_recently_played(limit=50)['next']
# Out:
# 'https://api.spotify.com/v1/me/player/recently-played?before=1623870310702&limit=50'

# %%
st_use = st[60:-9]

# %%
cassie_acct.sp.current_user_recently_played(limit=50, after=st_use)
# Out:
# {'items': [{'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZHPrnImGh4re3TbSNkoZl'},
#        'href': 'https://api.spotify.com/v1/artists/0ZHPrnImGh4re3TbSNkoZl',
#        'id': '0ZHPrnImGh4re3TbSNkoZl',
#        'name': 'Beret',
#        'type': 'artist',
#        'uri': 'spotify:artist:0ZHPrnImGh4re3TbSNkoZl'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5C4PDR4LnhZTbVnKWXuDKD'},
#        'href': 'https://api.spotify.com/v1/artists/5C4PDR4LnhZTbVnKWXuDKD',
#        'id': '5C4PDR4LnhZTbVnKWXuDKD',
#        'name': 'Morat',
#        'type': 'artist',
#        'uri': 'spotify:artist:5C4PDR4LnhZTbVnKWXuDKD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5m71js7NkNRQNtS1wmfH7s'},
#      'href': 'https://api.spotify.com/v1/albums/5m71js7NkNRQNtS1wmfH7s',
#      'id': '5m71js7NkNRQNtS1wmfH7s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734cac4c4431908529b744ec9b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024cac4c4431908529b744ec9b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514cac4c4431908529b744ec9b',
#        'width': 64}],
#      'name': 'Porfa no te vayas',
#      'release_date': '2021-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5m71js7NkNRQNtS1wmfH7s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ZHPrnImGh4re3TbSNkoZl'},
#       'href': 'https://api.spotify.com/v1/artists/0ZHPrnImGh4re3TbSNkoZl',
#       'id': '0ZHPrnImGh4re3TbSNkoZl',
#       'name': 'Beret',
#       'type': 'artist',
#       'uri': 'spotify:artist:0ZHPrnImGh4re3TbSNkoZl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5C4PDR4LnhZTbVnKWXuDKD'},
#       'href': 'https://api.spotify.com/v1/artists/5C4PDR4LnhZTbVnKWXuDKD',
#       'id': '5C4PDR4LnhZTbVnKWXuDKD',
#       'name': 'Morat',
#       'type': 'artist',
#       'uri': 'spotify:artist:5C4PDR4LnhZTbVnKWXuDKD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 209712,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5152100363'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4J2HLNTxiVxxs6kWgTIN43'},
#     'href': 'https://api.spotify.com/v1/tracks/4J2HLNTxiVxxs6kWgTIN43',
#     'id': '4J2HLNTxiVxxs6kWgTIN43',
#     'is_local': False,
#     'name': 'Porfa no te vayas',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53e54e59e04f5fdaaef316461c81da19854d5014?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4J2HLNTxiVxxs6kWgTIN43'},
#    'played_at': '2021-06-19T21:37:48.696Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#        'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#        'id': '07YUOmWljBTXwIseAUd9TW',
#        'name': 'Sebastian Yatra',
#        'type': 'artist',
#        'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Zyj0zwOksGYLbLAZOaC31'},
#      'href': 'https://api.spotify.com/v1/albums/5Zyj0zwOksGYLbLAZOaC31',
#      'id': '5Zyj0zwOksGYLbLAZOaC31',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273194331547eaabec350413225',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02194331547eaabec350413225',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851194331547eaabec350413225',
#        'width': 64}],
#      'name': 'FANTASÍA',
#      'release_date': '2019-04-12',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5Zyj0zwOksGYLbLAZOaC31'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#       'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#       'id': '07YUOmWljBTXwIseAUd9TW',
#       'name': 'Sebastian Yatra',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 155093,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71903641'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0c8JmuKzaREJu3kUqoBfmo'},
#     'href': 'https://api.spotify.com/v1/tracks/0c8JmuKzaREJu3kUqoBfmo',
#     'id': '0c8JmuKzaREJu3kUqoBfmo',
#     'is_local': False,
#     'name': 'Elena',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/80eceb53fc06a4a1d53041840fa8c80f364def33?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0c8JmuKzaREJu3kUqoBfmo'},
#    'played_at': '2021-06-19T21:21:07.585Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#        'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#        'id': '2KxjMGXFgX1vt9grpbD3xI',
#        'name': 'Dvicio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5MDL4gSUSx0jtWnvQhluw2'},
#      'href': 'https://api.spotify.com/v1/albums/5MDL4gSUSx0jtWnvQhluw2',
#      'id': '5MDL4gSUSx0jtWnvQhluw2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360801ca1f4ec231a801d7055',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260801ca1f4ec231a801d7055',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160801ca1f4ec231a801d7055',
#        'width': 64}],
#      'name': 'Impulso',
#      'release_date': '2020-03-19',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5MDL4gSUSx0jtWnvQhluw2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#       'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#       'id': '2KxjMGXFgX1vt9grpbD3xI',
#       'name': 'Dvicio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0vR2qb8m9WHeZ5ByCbimq2'},
#       'href': 'https://api.spotify.com/v1/artists/0vR2qb8m9WHeZ5ByCbimq2',
#       'id': '0vR2qb8m9WHeZ5ByCbimq2',
#       'name': 'Reik',
#       'type': 'artist',
#       'uri': 'spotify:artist:0vR2qb8m9WHeZ5ByCbimq2'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6tkyhGe9hGI3Lcfo4gVh6Z'},
#       'href': 'https://api.spotify.com/v1/artists/6tkyhGe9hGI3Lcfo4gVh6Z',
#       'id': '6tkyhGe9hGI3Lcfo4gVh6Z',
#       'name': 'ChocQuibTown',
#       'type': 'artist',
#       'uri': 'spotify:artist:6tkyhGe9hGI3Lcfo4gVh6Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 219189,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5021901613'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0AJKRuWjsVn6B43gm5HfjV'},
#     'href': 'https://api.spotify.com/v1/tracks/0AJKRuWjsVn6B43gm5HfjV',
#     'id': '0AJKRuWjsVn6B43gm5HfjV',
#     'is_local': False,
#     'name': 'DOSIS',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/78360587e5a9113fe78d07da680dadec53b3a12e?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0AJKRuWjsVn6B43gm5HfjV'},
#    'played_at': '2021-06-19T21:18:32.111Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#        'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#        'id': '2KxjMGXFgX1vt9grpbD3xI',
#        'name': 'Dvicio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/694hCUyeR4sSjV7J1mu0dO'},
#      'href': 'https://api.spotify.com/v1/albums/694hCUyeR4sSjV7J1mu0dO',
#      'id': '694hCUyeR4sSjV7J1mu0dO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ae7c5684b1731028ad21d7fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ae7c5684b1731028ad21d7fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ae7c5684b1731028ad21d7fb',
#        'width': 64}],
#      'name': 'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:694hCUyeR4sSjV7J1mu0dO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#       'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#       'id': '2KxjMGXFgX1vt9grpbD3xI',
#       'name': 'Dvicio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5W9RX9DoA3MSvQGnoIgs7X'},
#       'href': 'https://api.spotify.com/v1/artists/5W9RX9DoA3MSvQGnoIgs7X',
#       'id': '5W9RX9DoA3MSvQGnoIgs7X',
#       'name': 'Jesús Reik',
#       'type': 'artist',
#       'uri': 'spotify:artist:5W9RX9DoA3MSvQGnoIgs7X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wkoKEfS6dXwThbyTnZWFU'},
#       'href': 'https://api.spotify.com/v1/artists/2wkoKEfS6dXwThbyTnZWFU',
#       'id': '2wkoKEfS6dXwThbyTnZWFU',
#       'name': 'Mau y Ricky',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wkoKEfS6dXwThbyTnZWFU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 212348,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5021800196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4txQPJDlvU72lC6EMhT7m9'},
#     'href': 'https://api.spotify.com/v1/tracks/4txQPJDlvU72lC6EMhT7m9',
#     'id': '4txQPJDlvU72lC6EMhT7m9',
#     'is_local': False,
#     'name': 'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16db5d7291e9c6d7dc025cd30fe1acf15a06bd38?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4txQPJDlvU72lC6EMhT7m9'},
#    'played_at': '2021-06-19T21:14:43.964Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#        'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#        'id': '2KxjMGXFgX1vt9grpbD3xI',
#        'name': 'Dvicio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/694hCUyeR4sSjV7J1mu0dO'},
#      'href': 'https://api.spotify.com/v1/albums/694hCUyeR4sSjV7J1mu0dO',
#      'id': '694hCUyeR4sSjV7J1mu0dO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ae7c5684b1731028ad21d7fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ae7c5684b1731028ad21d7fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ae7c5684b1731028ad21d7fb',
#        'width': 64}],
#      'name': 'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#      'release_date': '2018-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:694hCUyeR4sSjV7J1mu0dO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#       'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#       'id': '2KxjMGXFgX1vt9grpbD3xI',
#       'name': 'Dvicio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5W9RX9DoA3MSvQGnoIgs7X'},
#       'href': 'https://api.spotify.com/v1/artists/5W9RX9DoA3MSvQGnoIgs7X',
#       'id': '5W9RX9DoA3MSvQGnoIgs7X',
#       'name': 'Jesús Reik',
#       'type': 'artist',
#       'uri': 'spotify:artist:5W9RX9DoA3MSvQGnoIgs7X'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wkoKEfS6dXwThbyTnZWFU'},
#       'href': 'https://api.spotify.com/v1/artists/2wkoKEfS6dXwThbyTnZWFU',
#       'id': '2wkoKEfS6dXwThbyTnZWFU',
#       'name': 'Mau y Ricky',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wkoKEfS6dXwThbyTnZWFU'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 212348,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5021800196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4txQPJDlvU72lC6EMhT7m9'},
#     'href': 'https://api.spotify.com/v1/tracks/4txQPJDlvU72lC6EMhT7m9',
#     'id': '4txQPJDlvU72lC6EMhT7m9',
#     'is_local': False,
#     'name': 'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/16db5d7291e9c6d7dc025cd30fe1acf15a06bd38?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4txQPJDlvU72lC6EMhT7m9'},
#    'played_at': '2021-06-19T21:04:32.872Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eLcDZDYHXZCebtQmVFL25'},
#        'href': 'https://api.spotify.com/v1/artists/7eLcDZDYHXZCebtQmVFL25',
#        'id': '7eLcDZDYHXZCebtQmVFL25',
#        'name': 'Aitana',
#        'type': 'artist',
#        'uri': 'spotify:artist:7eLcDZDYHXZCebtQmVFL25'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0e1CKKCDX94OvUk79Zlr9D'},
#      'href': 'https://api.spotify.com/v1/albums/0e1CKKCDX94OvUk79Zlr9D',
#      'id': '0e1CKKCDX94OvUk79Zlr9D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27355e92f2e43daa029f60fd4e6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0255e92f2e43daa029f60fd4e6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485155e92f2e43daa029f60fd4e6',
#        'width': 64}],
#      'name': '11 RAZONES',
#      'release_date': '2020-12-10',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0e1CKKCDX94OvUk79Zlr9D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7eLcDZDYHXZCebtQmVFL25'},
#       'href': 'https://api.spotify.com/v1/artists/7eLcDZDYHXZCebtQmVFL25',
#       'id': '7eLcDZDYHXZCebtQmVFL25',
#       'name': 'Aitana',
#       'type': 'artist',
#       'uri': 'spotify:artist:7eLcDZDYHXZCebtQmVFL25'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Zs59sqZJ6fWQqWbRC8bOP'},
#       'href': 'https://api.spotify.com/v1/artists/3Zs59sqZJ6fWQqWbRC8bOP',
#       'id': '3Zs59sqZJ6fWQqWbRC8bOP',
#       'name': 'Natalia Lacunza',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Zs59sqZJ6fWQqWbRC8bOP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 167192,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5702002176'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3vrslkAmBQ4mvqfOX1Xc6Q'},
#     'href': 'https://api.spotify.com/v1/tracks/3vrslkAmBQ4mvqfOX1Xc6Q',
#     'id': '3vrslkAmBQ4mvqfOX1Xc6Q',
#     'is_local': False,
#     'name': 'CUANDO TE FUISTE',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a58bed14d8f7c843319ff9861d0ecc7d76d618ed?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3vrslkAmBQ4mvqfOX1Xc6Q'},
#    'played_at': '2021-06-19T20:47:27.816Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/6EwpIC3NLeemswSWEbDADy'},
#     'href': 'https://api.spotify.com/v1/playlists/6EwpIC3NLeemswSWEbDADy',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6EwpIC3NLeemswSWEbDADy'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#        'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#        'id': '2KxjMGXFgX1vt9grpbD3xI',
#        'name': 'Dvicio',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/22P1OY4TRFRwhP0q29loQ8'},
#        'href': 'https://api.spotify.com/v1/artists/22P1OY4TRFRwhP0q29loQ8',
#        'id': '22P1OY4TRFRwhP0q29loQ8',
#        'name': 'Lali',
#        'type': 'artist',
#        'uri': 'spotify:artist:22P1OY4TRFRwhP0q29loQ8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4AnSVmFc7AjBJmiifMZbh2'},
#      'href': 'https://api.spotify.com/v1/albums/4AnSVmFc7AjBJmiifMZbh2',
#      'id': '4AnSVmFc7AjBJmiifMZbh2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f0ed8e49ebddf6a36dc49854',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f0ed8e49ebddf6a36dc49854',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f0ed8e49ebddf6a36dc49854',
#        'width': 64}],
#      'name': 'Soy de Volar',
#      'release_date': '2020-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4AnSVmFc7AjBJmiifMZbh2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KxjMGXFgX1vt9grpbD3xI'},
#       'href': 'https://api.spotify.com/v1/artists/2KxjMGXFgX1vt9grpbD3xI',
#       'id': '2KxjMGXFgX1vt9grpbD3xI',
#       'name': 'Dvicio',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KxjMGXFgX1vt9grpbD3xI'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/22P1OY4TRFRwhP0q29loQ8'},
#       'href': 'https://api.spotify.com/v1/artists/22P1OY4TRFRwhP0q29loQ8',
#       'id': '22P1OY4TRFRwhP0q29loQ8',
#       'name': 'Lali',
#       'type': 'artist',
#       'uri': 'spotify:artist:22P1OY4TRFRwhP0q29loQ8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
# ...
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 117495,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ121644250'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MdZQXUBijQxcBkYz4G1Z5'},
#     'href': 'https://api.spotify.com/v1/tracks/7MdZQXUBijQxcBkYz4G1Z5',
#     'id': '7MdZQXUBijQxcBkYz4G1Z5',
#     'is_local': False,
#     'name': 'Affection',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53495b26f172a1388402767e44b4f1bd87e86e0a?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:7MdZQXUBijQxcBkYz4G1Z5'},
#    'played_at': '2021-06-16T19:11:35.152Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1CDGyk68UnX5LzOQArGv9h'},
#     'href': 'https://api.spotify.com/v1/playlists/1CDGyk68UnX5LzOQArGv9h',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1CDGyk68UnX5LzOQArGv9h'}},
#   {'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5b0XQwyoJBFd3MwL2YxEPO'},
#        'href': 'https://api.spotify.com/v1/artists/5b0XQwyoJBFd3MwL2YxEPO',
#        'id': '5b0XQwyoJBFd3MwL2YxEPO',
#        'name': 'Nohidea',
#        'type': 'artist',
#        'uri': 'spotify:artist:5b0XQwyoJBFd3MwL2YxEPO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3IeZJRDlyJdbgF64pkMlqc'},
#      'href': 'https://api.spotify.com/v1/albums/3IeZJRDlyJdbgF64pkMlqc',
#      'id': '3IeZJRDlyJdbgF64pkMlqc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fd2bcbe5eb8cd4339bc586f3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fd2bcbe5eb8cd4339bc586f3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fd2bcbe5eb8cd4339bc586f3',
#        'width': 64}],
#      'name': 'osho',
#      'release_date': '2017-02-04',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3IeZJRDlyJdbgF64pkMlqc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5b0XQwyoJBFd3MwL2YxEPO'},
#       'href': 'https://api.spotify.com/v1/artists/5b0XQwyoJBFd3MwL2YxEPO',
#       'id': '5b0XQwyoJBFd3MwL2YxEPO',
#       'name': 'Nohidea',
#       'type': 'artist',
#       'uri': 'spotify:artist:5b0XQwyoJBFd3MwL2YxEPO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 108665,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM42K1704515'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6CoH2HgpHBhUnrWtOutPSR'},
#     'href': 'https://api.spotify.com/v1/tracks/6CoH2HgpHBhUnrWtOutPSR',
#     'id': '6CoH2HgpHBhUnrWtOutPSR',
#     'is_local': False,
#     'name': 'haiku',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/986ed8129bbaf3fb23bec9947358ba91b108609a?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6CoH2HgpHBhUnrWtOutPSR'},
#    'played_at': '2021-06-16T19:09:37.686Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1CDGyk68UnX5LzOQArGv9h'},
#     'href': 'https://api.spotify.com/v1/playlists/1CDGyk68UnX5LzOQArGv9h',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1CDGyk68UnX5LzOQArGv9h'}},
#   {'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4rF7c8zpCKzuSXohs2HIpA'},
#        'href': 'https://api.spotify.com/v1/artists/4rF7c8zpCKzuSXohs2HIpA',
#        'id': '4rF7c8zpCKzuSXohs2HIpA',
#        'name': 'Steven Universe',
#        'type': 'artist',
#        'uri': 'spotify:artist:4rF7c8zpCKzuSXohs2HIpA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UvcAGFyfXmydWCFZve1LQ'},
#      'href': 'https://api.spotify.com/v1/albums/4UvcAGFyfXmydWCFZve1LQ',
#      'id': '4UvcAGFyfXmydWCFZve1LQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739eb0f82cc0719c0fdde9a465',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029eb0f82cc0719c0fdde9a465',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519eb0f82cc0719c0fdde9a465',
#        'width': 64}],
#      'name': 'Steven Universe The Movie (Original Soundtrack) [Deluxe Version]',
#      'release_date': '2019-12-06',
#      'release_date_precision': 'day',
#      'total_tracks': 46,
#      'type': 'album',
#      'uri': 'spotify:album:4UvcAGFyfXmydWCFZve1LQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4rF7c8zpCKzuSXohs2HIpA'},
#       'href': 'https://api.spotify.com/v1/artists/4rF7c8zpCKzuSXohs2HIpA',
#       'id': '4rF7c8zpCKzuSXohs2HIpA',
#       'name': 'Steven Universe',
#       'type': 'artist',
#       'uri': 'spotify:artist:4rF7c8zpCKzuSXohs2HIpA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2gRQpWDHAdGJuzYYg7IFns'},
#       'href': 'https://api.spotify.com/v1/artists/2gRQpWDHAdGJuzYYg7IFns',
#       'id': '2gRQpWDHAdGJuzYYg7IFns',
#       'name': 'Jeff Liu',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gRQpWDHAdGJuzYYg7IFns'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Pd7FRVtwNxFsQIkDMpLGz'},
#       'href': 'https://api.spotify.com/v1/artists/6Pd7FRVtwNxFsQIkDMpLGz',
#       'id': '6Pd7FRVtwNxFsQIkDMpLGz',
#       'name': 'Rebecca Sugar',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Pd7FRVtwNxFsQIkDMpLGz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 133000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR1900466'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5XHUgSDGWwbEpT94ZTi9r5'},
#     'href': 'https://api.spotify.com/v1/tracks/5XHUgSDGWwbEpT94ZTi9r5',
#     'id': '5XHUgSDGWwbEpT94ZTi9r5',
#     'is_local': False,
#     'name': 'No Matter What (feat. Rebecca Sugar & Jeff Liu) - Demo',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1581abbceba9bdd447b375d7dfebc540c9f541ef?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 41,
#     'type': 'track',
#     'uri': 'spotify:track:5XHUgSDGWwbEpT94ZTi9r5'},
#    'played_at': '2021-06-16T19:07:37.572Z',
#    'context': {'external_urls': {'spotify': 'https://open.spotify.com/playlist/1CDGyk68UnX5LzOQArGv9h'},
#     'href': 'https://api.spotify.com/v1/playlists/1CDGyk68UnX5LzOQArGv9h',
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1CDGyk68UnX5LzOQArGv9h'}}],
#  'next': 'https://api.spotify.com/v1/me/player/recently-played?after=1624138668696&limit=50',
#  'cursors': {'after': '1624138668696', 'before': '1623870457572'},
#  'limit': 50,
#  'href': 'https://api.spotify.com/v1/me/player/recently-played?after=1623870310702&limit=50'}

# %%
st = 'https://api.spotify.com/v1/me/player/recently-played?before=1623870310702&limit=50'

# %%
cassie_acct.sp.current_user_recently_played(before="1624138668696")['cursors']
# Out:
# {'Affection',
#  'All',
#  'As the World Caves In',
#  'Astronaut In The Ocean',
#  'Blurred Lines',
#  'Brand New Day',
#  'CUANDO TE FUISTE',
#  'Corazón Sin Vida',
#  'Corner of Queen',
#  'DOSIS',
#  'Elena',
#  'Flowers',
#  'Get Out',
#  'Grass',
#  'Happy Now',
#  "International Super Spy (There's One Thing You Can Expect from Me and That's the Unexpected)",
#  'Intro',
#  'Keyframe',
#  'No Matter What (feat. Rebecca Sugar & Jeff Liu) - Demo',
#  'Pompeii - Remix',
#  'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#  'Snakes & Smoke',
#  'Sorry',
#  'Soy de Volar',
#  'The Little Dream',
#  "There's No Such Thing as Happily Ever After",
#  'Us',
#  'We Are the Crystal Gems (From "Steven Universe") [Orchestrated]',
#  'calles',
#  'good 4 u',
#  'haiku',
#  'oneofone_rwrk',
#  'sincerely, yours'}

# %%
set(x['track']['name'] for x in cassie_acct.sp.current_user_recently_played(after="1623870310702")['items'])
# Out:
# {'Affection',
#  'All',
#  'As the World Caves In',
#  'Astronaut In The Ocean',
#  'Blurred Lines',
#  'Brand New Day',
#  'CUANDO TE FUISTE',
#  'Corazón Sin Vida',
#  'Corner of Queen',
#  'DOSIS',
#  'Elena',
#  'Flowers',
#  'Get Out',
#  'Grass',
#  'Happy Now',
#  "International Super Spy (There's One Thing You Can Expect from Me and That's the Unexpected)",
#  'Intro',
#  'Keyframe',
#  'No Matter What (feat. Rebecca Sugar & Jeff Liu) - Demo',
#  'Pompeii - Remix',
#  'Porfa no te vayas',
#  'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#  'Snakes & Smoke',
#  'Sorry',
#  'Soy de Volar',
#  'The Little Dream',
#  "There's No Such Thing as Happily Ever After",
#  'Us',
#  'calles',
#  'good 4 u',
#  'haiku',
#  'oneofone_rwrk',
#  'sincerely, yours'}

# %%
set(x['track']['name'] for x in cassie_acct.sp.current_user_recently_played(limit=50, before='1624138668696')['items'])

# %%
{'after': '1624138668696', 'before': '1623870310702'}

# %%
# only works for SIGNED IN USER -> recently played songs.
set(x['track']['name'] for x in cassie_acct.sp.current_user_recently_played()['items'])
# Out:
# {'Affection',
#  'All',
#  'As the World Caves In',
#  'Astronaut In The Ocean',
#  'Blurred Lines',
#  'Brand New Day',
#  'CUANDO TE FUISTE',
#  'Corazón Sin Vida',
#  'Corner of Queen',
#  'DOSIS',
#  'Elena',
#  'Flowers',
#  'Get Out',
#  'Grass',
#  'Happy Now',
#  "International Super Spy (There's One Thing You Can Expect from Me and That's the Unexpected)",
#  'Intro',
#  'Keyframe',
#  'No Matter What (feat. Rebecca Sugar & Jeff Liu) - Demo',
#  'Pompeii - Remix',
#  'Porfa no te vayas',
#  'Qué Tienes Tú (feat. Jesús de Reik & Mau y Ricky)',
#  'Snakes & Smoke',
#  'Sorry',
#  'Soy de Volar',
#  'The Little Dream',
#  "There's No Such Thing as Happily Ever After",
#  'Us',
#  'We Are the Crystal Gems (From "Steven Universe") [Orchestrated]',
#  'calles',
#  'good 4 u',
#  'haiku',
#  'oneofone_rwrk',
#  'sincerely, yours'}

# %%
ben_acct.sp.current_user_saved_tracks()
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=20',
#  'items': [{'added_at': '2021-06-17T18:17:03Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DHHaCy2ri351JypVkX9B0'},
#        'href': 'https://api.spotify.com/v1/artists/1DHHaCy2ri351JypVkX9B0',
#        'id': '1DHHaCy2ri351JypVkX9B0',
#        'name': 'MADAX',
#        'type': 'artist',
#        'uri': 'spotify:artist:1DHHaCy2ri351JypVkX9B0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Xfw8WsO5Qbh9o1q8E3M5n'},
#      'href': 'https://api.spotify.com/v1/albums/5Xfw8WsO5Qbh9o1q8E3M5n',
#      'id': '5Xfw8WsO5Qbh9o1q8E3M5n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27352a7abb1c902389ba65a1458',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0252a7abb1c902389ba65a1458',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485152a7abb1c902389ba65a1458',
#        'width': 64}],
#      'name': "International Super Spy (There's One Thing You Can Expect from Me and That's the Unexpected)",
#      'release_date': '2021-06-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5Xfw8WsO5Qbh9o1q8E3M5n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DHHaCy2ri351JypVkX9B0'},
#       'href': 'https://api.spotify.com/v1/artists/1DHHaCy2ri351JypVkX9B0',
#       'id': '1DHHaCy2ri351JypVkX9B0',
#       'name': 'MADAX',
#       'type': 'artist',
#       'uri': 'spotify:artist:1DHHaCy2ri351JypVkX9B0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 104347,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHZ52151931'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3stmJrCREkTguKJtklMLQd'},
#     'href': 'https://api.spotify.com/v1/tracks/3stmJrCREkTguKJtklMLQd',
#     'id': '3stmJrCREkTguKJtklMLQd',
#     'is_local': False,
#     'name': "International Super Spy (There's One Thing You Can Expect from Me and That's the Unexpected)",
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ba89d4551e15959d37e7eb940b6f370763b3aa8c?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3stmJrCREkTguKJtklMLQd'}},
#   {'added_at': '2021-06-17T14:37:29Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kft86DbqCNr7rjq3pEj0G'},
#        'href': 'https://api.spotify.com/v1/artists/3kft86DbqCNr7rjq3pEj0G',
#        'id': '3kft86DbqCNr7rjq3pEj0G',
#        'name': 'Sarah Cothran',
#        'type': 'artist',
#        'uri': 'spotify:artist:3kft86DbqCNr7rjq3pEj0G'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fy6bIIBMLjfdvyPpmv8Ci'},
#      'href': 'https://api.spotify.com/v1/albums/7fy6bIIBMLjfdvyPpmv8Ci',
#      'id': '7fy6bIIBMLjfdvyPpmv8Ci',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b2757e9381a2b0e2d4a94216',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b2757e9381a2b0e2d4a94216',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b2757e9381a2b0e2d4a94216',
#        'width': 64}],
#      'name': 'As the World Caves In',
#      'release_date': '2021-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7fy6bIIBMLjfdvyPpmv8Ci'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3kft86DbqCNr7rjq3pEj0G'},
#       'href': 'https://api.spotify.com/v1/artists/3kft86DbqCNr7rjq3pEj0G',
#       'id': '3kft86DbqCNr7rjq3pEj0G',
#       'name': 'Sarah Cothran',
#       'type': 'artist',
#       'uri': 'spotify:artist:3kft86DbqCNr7rjq3pEj0G'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 161612,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHNB2115936'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7LAmsNJpBaNvNg7VZPXxSv'},
#     'href': 'https://api.spotify.com/v1/tracks/7LAmsNJpBaNvNg7VZPXxSv',
#     'id': '7LAmsNJpBaNvNg7VZPXxSv',
#     'is_local': False,
#     'name': 'As the World Caves In',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/110195ea3f64b50818a63c7163178db0f1ad74ee?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7LAmsNJpBaNvNg7VZPXxSv'}},
#   {'added_at': '2021-06-17T04:11:46Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1UxNUybRFdtksz3l5HtCEG'},
#        'href': 'https://api.spotify.com/v1/artists/1UxNUybRFdtksz3l5HtCEG',
#        'id': '1UxNUybRFdtksz3l5HtCEG',
#        'name': 'Casey Abrams',
#        'type': 'artist',
#        'uri': 'spotify:artist:1UxNUybRFdtksz3l5HtCEG'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FR',
#       'GB',
#       'GN',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KH',
#       'KR',
#       'KW',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'ME',
#       'MK',
#       'MO',
#       'MT',
#       'MU',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'TZ',
#       'UA',
#       'US',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6wq7YT3Nq1Qq5tB6DC8Ok7'},
#      'href': 'https://api.spotify.com/v1/albums/6wq7YT3Nq1Qq5tB6DC8Ok7',
#      'id': '6wq7YT3Nq1Qq5tB6DC8Ok7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e445e2108c08017a61eaa58',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e445e2108c08017a61eaa58',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e445e2108c08017a61eaa58',
#        'width': 64}],
#      'name': 'Casey Abrams',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6wq7YT3Nq1Qq5tB6DC8Ok7'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1UxNUybRFdtksz3l5HtCEG'},
#       'href': 'https://api.spotify.com/v1/artists/1UxNUybRFdtksz3l5HtCEG',
#       'id': '1UxNUybRFdtksz3l5HtCEG',
#       'name': 'Casey Abrams',
#       'type': 'artist',
#       'uri': 'spotify:artist:1UxNUybRFdtksz3l5HtCEG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KH',
#      'KR',
#      'KW',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MO',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'TZ',
#      'UA',
#      'US',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211920,
#     'explicit': False,
#     'external_ids': {'isrc': 'USC4R1200961'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2MeNSNQa0vSkGOq9bCrhmq'},
#     'href': 'https://api.spotify.com/v1/tracks/2MeNSNQa0vSkGOq9bCrhmq',
#     'id': '2MeNSNQa0vSkGOq9bCrhmq',
#     'is_local': False,
#     'name': 'Get Out',
#     'popularity': 40,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ff5854710d1a847954a0bb311e64ab9893005e20?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2MeNSNQa0vSkGOq9bCrhmq'}},
#   {'added_at': '2021-06-16T14:10:49Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YuDNxLxYszH1BrWRnkZgs'},
#        'href': 'https://api.spotify.com/v1/artists/5YuDNxLxYszH1BrWRnkZgs',
#        'id': '5YuDNxLxYszH1BrWRnkZgs',
#        'name': 'Sanj and the Bracelets',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YuDNxLxYszH1BrWRnkZgs'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6LqyY3u4AKE0UQVgM7ZiCf'},
#      'href': 'https://api.spotify.com/v1/albums/6LqyY3u4AKE0UQVgM7ZiCf',
#      'id': '6LqyY3u4AKE0UQVgM7ZiCf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef5f93b9070ee1b8f72312aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef5f93b9070ee1b8f72312aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef5f93b9070ee1b8f72312aa',
#        'width': 64}],
#      'name': 'How to Move',
#      'release_date': '2020-01-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6LqyY3u4AKE0UQVgM7ZiCf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YuDNxLxYszH1BrWRnkZgs'},
#       'href': 'https://api.spotify.com/v1/artists/5YuDNxLxYszH1BrWRnkZgs',
#       'id': '5YuDNxLxYszH1BrWRnkZgs',
#       'name': 'Sanj and the Bracelets',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YuDNxLxYszH1BrWRnkZgs'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 227256,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZFYW2089773'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Mz7Dl6yXHFpXppujrhVYA'},
#     'href': 'https://api.spotify.com/v1/tracks/0Mz7Dl6yXHFpXppujrhVYA',
#     'id': '0Mz7Dl6yXHFpXppujrhVYA',
#     'is_local': False,
#     'name': 'How to Move',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/52ef230ae053c93d7cfba036c8c0ecf28b14d1f1?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Mz7Dl6yXHFpXppujrhVYA'}},
#   {'added_at': '2021-06-16T14:10:32Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#        'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#        'id': '1WgXqy2Dd70QQOU7Ay074N',
#        'name': 'AURORA',
#        'type': 'artist',
#        'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4iSXUMDfkZMFLIEnkAWWDL'},
#      'href': 'https://api.spotify.com/v1/albums/4iSXUMDfkZMFLIEnkAWWDL',
#      'id': '4iSXUMDfkZMFLIEnkAWWDL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732c14247b6fc7e78106833a40',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022c14247b6fc7e78106833a40',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512c14247b6fc7e78106833a40',
#        'width': 64}],
#      'name': 'Into the Unknown',
#      'release_date': '2020-03-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4iSXUMDfkZMFLIEnkAWWDL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#       'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#       'id': '1WgXqy2Dd70QQOU7Ay074N',
#       'name': 'AURORA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 199960,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD12096167'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0O2szuaez7BKxS8SH7RkV4'},
#     'href': 'https://api.spotify.com/v1/tracks/0O2szuaez7BKxS8SH7RkV4',
#     'id': '0O2szuaez7BKxS8SH7RkV4',
#     'is_local': False,
#     'name': 'Into the Unknown',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/704d2c428afde1da87a65a3b91bbb4111adbb9e4?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0O2szuaez7BKxS8SH7RkV4'}},
#   {'added_at': '2021-06-16T13:30:27Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5BMigOit24OydSubgIiJxY'},
#        'href': 'https://api.spotify.com/v1/artists/5BMigOit24OydSubgIiJxY',
#        'id': '5BMigOit24OydSubgIiJxY',
#        'name': 'Serge Fiori',
#        'type': 'artist',
#        'uri': 'spotify:artist:5BMigOit24OydSubgIiJxY'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2A2PVNVEu5j1zPGof4VSXw'},
#      'href': 'https://api.spotify.com/v1/albums/2A2PVNVEu5j1zPGof4VSXw',
#      'id': '2A2PVNVEu5j1zPGof4VSXw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b29d0ae7197185619f0c1938',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b29d0ae7197185619f0c1938',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b29d0ae7197185619f0c1938',
#        'width': 64}],
#      'name': "Serge Fiori: Un musicien parmi tant d'autres",
#      'release_date': '2006-05-16',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2A2PVNVEu5j1zPGof4VSXw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5BMigOit24OydSubgIiJxY'},
#       'href': 'https://api.spotify.com/v1/artists/5BMigOit24OydSubgIiJxY',
#       'id': '5BMigOit24OydSubgIiJxY',
#       'name': 'Serge Fiori',
#       'type': 'artist',
#       'uri': 'spotify:artist:5BMigOit24OydSubgIiJxY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0IX0nppAnGjDz53emI5YAW'},
#       'href': 'https://api.spotify.com/v1/artists/0IX0nppAnGjDz53emI5YAW',
#       'id': '0IX0nppAnGjDz53emI5YAW',
#       'name': 'Marc Déry',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IX0nppAnGjDz53emI5YAW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 255400,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAZ520620101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5X2OiVr2caJt79JcE8XptZ'},
#     'href': 'https://api.spotify.com/v1/tracks/5X2OiVr2caJt79JcE8XptZ',
#     'id': '5X2OiVr2caJt79JcE8XptZ',
#     'is_local': False,
#     'name': "Aujourd'hui, je dis bonjour à la vie",
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8758e86c91605bf69fbabc7beee234b97e48228c?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5X2OiVr2caJt79JcE8XptZ'}},
#   {'added_at': '2021-06-11T18:49:58Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0m5XJwKGYyUjd3VMfcINCQ'},
#        'href': 'https://api.spotify.com/v1/artists/0m5XJwKGYyUjd3VMfcINCQ',
#        'id': '0m5XJwKGYyUjd3VMfcINCQ',
#        'name': 'Shpongle',
#        'type': 'artist',
#        'uri': 'spotify:artist:0m5XJwKGYyUjd3VMfcINCQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7mMDExyYEy5EmOlCxte951'},
#      'href': 'https://api.spotify.com/v1/albums/7mMDExyYEy5EmOlCxte951',
#      'id': '7mMDExyYEy5EmOlCxte951',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273abadac3c7cced537b8e57809',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02abadac3c7cced537b8e57809',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851abadac3c7cced537b8e57809',
#        'width': 64}],
#      'name': 'Nothing Lasts...but Nothing Is Lost (Remastered, 2019)',
#      'release_date': '2020-01-09',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:7mMDExyYEy5EmOlCxte951'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0m5XJwKGYyUjd3VMfcINCQ'},
#       'href': 'https://api.spotify.com/v1/artists/0m5XJwKGYyUjd3VMfcINCQ',
#       'id': '0m5XJwKGYyUjd3VMfcINCQ',
#       'name': 'Shpongle',
#       'type': 'artist',
#       'uri': 'spotify:artist:0m5XJwKGYyUjd3VMfcINCQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 95986,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA2P0502892'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6q6Etn2bpFRO59daD2r3Z5'},
#     'href': 'https://api.spotify.com/v1/tracks/6q6Etn2bpFRO59daD2r3Z5',
#     'id': '6q6Etn2bpFRO59daD2r3Z5',
#     'is_local': False,
#     'name': 'Linguistic Mystic - Remastered, 2019',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f0ddbabef767ab8f251164c13e5eb7aa21a539ca?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:6q6Etn2bpFRO59daD2r3Z5'}},
#   {'added_at': '2021-06-11T02:43:01Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nPOO9iTcrs9k6yFffPxjH'},
#        'href': 'https://api.spotify.com/v1/artists/5nPOO9iTcrs9k6yFffPxjH',
#        'id': '5nPOO9iTcrs9k6yFffPxjH',
#        'name': 'Röyksopp',
#        'type': 'artist',
#        'uri': 'spotify:artist:5nPOO9iTcrs9k6yFffPxjH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4WOZU9evfEO7eI6ICsoGN0'},
#      'href': 'https://api.spotify.com/v1/albums/4WOZU9evfEO7eI6ICsoGN0',
#      'id': '4WOZU9evfEO7eI6ICsoGN0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e5655cd8db911dc48ea57df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e5655cd8db911dc48ea57df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e5655cd8db911dc48ea57df',
#        'width': 64}],
#      'name': 'Melody A.M.',
#      'release_date': '2001-08-22',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4WOZU9evfEO7eI6ICsoGN0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5nPOO9iTcrs9k6yFffPxjH'},
#       'href': 'https://api.spotify.com/v1/artists/5nPOO9iTcrs9k6yFffPxjH',
#       'id': '5nPOO9iTcrs9k6yFffPxjH',
#       'name': 'Röyksopp',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nPOO9iTcrs9k6yFffPxjH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
# ...
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02291365c950592bee8e415f63',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851291365c950592bee8e415f63',
#        'width': 64}],
#      'name': 'Jason Derulo (International)',
#      'release_date': '2010-02-26',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:0DEsmIQ5ir7tz52Nkf4i1K'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07YZf4WDAMNwqr4jfgOZ8y'},
#       'href': 'https://api.spotify.com/v1/artists/07YZf4WDAMNwqr4jfgOZ8y',
#       'id': '07YZf4WDAMNwqr4jfgOZ8y',
#       'name': 'Jason Derulo',
#       'type': 'artist',
#       'uri': 'spotify:artist:07YZf4WDAMNwqr4jfgOZ8y'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 199026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10904633'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6St9lR6dhV2tpCNVz7qfrS'},
#     'href': 'https://api.spotify.com/v1/tracks/6St9lR6dhV2tpCNVz7qfrS',
#     'id': '6St9lR6dhV2tpCNVz7qfrS',
#     'is_local': False,
#     'name': 'In My Head',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/446c66f2946007c502342d167284f6e3a02c7705?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6St9lR6dhV2tpCNVz7qfrS'}},
#   {'added_at': '2021-05-29T02:24:49Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mxMScEBCgMVnxWKrYr1YD'},
#        'href': 'https://api.spotify.com/v1/artists/7mxMScEBCgMVnxWKrYr1YD',
#        'id': '7mxMScEBCgMVnxWKrYr1YD',
#        'name': 'Heather LaRose',
#        'type': 'artist',
#        'uri': 'spotify:artist:7mxMScEBCgMVnxWKrYr1YD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ogdksvtz41c8EQxZTg4Qu'},
#      'href': 'https://api.spotify.com/v1/albums/2ogdksvtz41c8EQxZTg4Qu',
#      'id': '2ogdksvtz41c8EQxZTg4Qu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ce81dcbde8d834078c84de91',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ce81dcbde8d834078c84de91',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ce81dcbde8d834078c84de91',
#        'width': 64}],
#      'name': 'The Valley',
#      'release_date': '2020-08-27',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2ogdksvtz41c8EQxZTg4Qu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mxMScEBCgMVnxWKrYr1YD'},
#       'href': 'https://api.spotify.com/v1/artists/7mxMScEBCgMVnxWKrYr1YD',
#       'id': '7mxMScEBCgMVnxWKrYr1YD',
#       'name': 'Heather LaRose',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mxMScEBCgMVnxWKrYr1YD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 206315,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMEZE1773201'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6WUBrg4MIM7BtPKByzr3Ze'},
#     'href': 'https://api.spotify.com/v1/tracks/6WUBrg4MIM7BtPKByzr3Ze',
#     'id': '6WUBrg4MIM7BtPKByzr3Ze',
#     'is_local': False,
#     'name': 'The Valley',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6961fb78b0a2ecf1dfa96db1d2d2e62c64286e38?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6WUBrg4MIM7BtPKByzr3Ze'}},
#   {'added_at': '2021-05-19T15:48:42Z',
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pQXfjCzKMCrcQnp9TAn3z'},
#        'href': 'https://api.spotify.com/v1/artists/7pQXfjCzKMCrcQnp9TAn3z',
#        'id': '7pQXfjCzKMCrcQnp9TAn3z',
#        'name': 'The Westerlies',
#        'type': 'artist',
#        'uri': 'spotify:artist:7pQXfjCzKMCrcQnp9TAn3z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4tePkY22x36QdX2zzfc2vS'},
#      'href': 'https://api.spotify.com/v1/albums/4tePkY22x36QdX2zzfc2vS',
#      'id': '4tePkY22x36QdX2zzfc2vS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd913e51c6811920cd36b3a1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd913e51c6811920cd36b3a1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd913e51c6811920cd36b3a1',
#        'width': 64}],
#      'name': 'Robert Henry',
#      'release_date': '2019-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4tePkY22x36QdX2zzfc2vS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7pQXfjCzKMCrcQnp9TAn3z'},
#       'href': 'https://api.spotify.com/v1/artists/7pQXfjCzKMCrcQnp9TAn3z',
#       'id': '7pQXfjCzKMCrcQnp9TAn3z',
#       'name': 'The Westerlies',
#       'type': 'artist',
#       'uri': 'spotify:artist:7pQXfjCzKMCrcQnp9TAn3z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 322586,
#     'explicit': False,
#     'external_ids': {'isrc': 'USME31901008'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2p5fhhH6ZEwTIoTmArlkDd'},
#     'href': 'https://api.spotify.com/v1/tracks/2p5fhhH6ZEwTIoTmArlkDd',
#     'id': '2p5fhhH6ZEwTIoTmArlkDd',
#     'is_local': False,
#     'name': 'Robert Henry',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8c1a3ac417fcb261d6911298d9be4a6817e44bfe?cid=a7a7510a67034ce28856364ce96c5504',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2p5fhhH6ZEwTIoTmArlkDd'}}],
#  'limit': 20,
#  'next': 'https://api.spotify.com/v1/me/tracks?offset=20&limit=20',
#  'offset': 0,
#  'previous': None,
#  'total': 996}

# %%
ben_acct = Sameify(user_ids['Ben'],read_only=True)
# Out:
#     playlist_name  num_tracks
# 2        Workout!         222
# 8   Golden Oldies         385
# 11        Writing         113
# 15        Running         613
# The following playlists have over 100 tracks. Do you want to exclude any of these from the program?
# If so, please list the index numbers in a comma separated list. (e.g. "1,2,5,10").
# For all playlists, please type "all".2,8,11,15
# This may load up to 117 songs, which will take approximately 13 seconds. Please type Y to continuey

# %%
ben_acct.personal_tracks
# Out:
#                playlist_id            playlist_name  \
# 0   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 1   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 2   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 3   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 4   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 5   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 6   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 7   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 8   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 9   4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 10  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 11  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 12  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 13  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 14  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 15  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 16  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 17  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 18  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 19  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 20  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 21  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 22  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 23  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 24  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 25  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 26  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 27  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 28  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 29  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 30  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 31  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 32  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 33  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 34  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 35  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 36  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 37  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 38  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 39  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 40  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 41  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 42  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 43  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 44  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 45  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 46  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 47  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 48  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 49  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 50  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 51  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 52  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 53  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 54  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 55  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 56  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 57  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 58  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 59  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 60  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 61  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 62  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 63  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 64  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 65  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 66  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 67  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 68  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 69  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 70  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 71  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 72  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 73  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 74  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 75  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 76  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 77  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 78  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 79  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 80  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 81  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 82  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 83  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 84  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 85  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 86  4AgXIKASWMr5rsjloJNPrP  Ben's Music Charcuterie
# 0   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 1   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 2   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 3   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 4   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 5   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 6   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 7   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 8   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 9   5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 10  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 11  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 12  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 13  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 14  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 15  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 16  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 17  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 18  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 19  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 20  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 21  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 22  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 23  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 24  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 25  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 26  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 27  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 28  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
# 29  5fwPrcSx7AeHaddJgU4Um6       Marcy's Music Recs
#
#                                            track_name                track_id  \
# 0                                     Murder! Murder!  2z2rcCzS0jBTya2SwQZIpW
# 1                                   The Devil in Camp  6jfV9Y5nVFRzcHCxRgaGMC
# 2                            Pumped up Kicks (Room 0)  0Rx4vXgplon2ozMhds93V1
# 3                                  Come to the Circus  4k9fR7zBEvwyN9j0GUEYbg
# 4                                  If I Told You Once  0Jkl79sElTWQnUr534STeJ
# 5                                       We're All Mad  5KUqeG9pyDA2YgI2o4YIwm
# 6                                  A Bar In Amsterdam  0ytvlQNCJmSY6l6a840U5A
# 7                                 Rock-Paper-Scissors  5AErfeSAv0NPSivHpe12AU
# 8                                    Soviet Trumpeter  46Cec5dxngueMCy0IBO3YJ
# 9                                    Fear Of The Dark  3NvI1qSyQoFlsXg97jVVNM
# 10                                            Javelin  3pKrxpx71RK0MFoCg1l2Ew
# 11                                      Trust in Rust  4PdrfzPj5D48xykbhLOHP7
# 12                                    Go Get Your Gun  4KOxCZLwedKjCJlZzr3M9R
# 13                               The Death of the Cog  3SokYcSBJpLmPt3HH6b2uE
# 14                                       Burn It Down  4Fz63h1gjK9xVB47Na4CaJ
# 13                                A Night on the Town  5nVjujWglwDnhlAjXFNsdI
# 14                                              Drink  5Hzto0vLxLb8GfkUtu6ZJK
# 15                              Fucked with an Anchor  2dgex0FiYtsHguA8D5WScn
# 16                                         Keelhauled  6pKA3P1JERZutikZtZpoUo
# 17                                             Mexico  35cnc4XqirI3CzVMIaQQWP
# 18                         Treasure Chest Party Quest  1hiaLyqpVlJSSlaWNl22Hb
# 19                                           Helvegen  1bqmaIBGwlo4MtrAxjRDHB
# 20                                               Fehu  528KWNngYORvUkoixWpqqy
# 21                                          Lyfjaberg  5iRCFYfU71YToV9UssimKe
# 22                                          Solringen  01pGPwb1OkC5JflWmcqeYQ
# 23                                          Solringen  01pGPwb1OkC5JflWmcqeYQ
# 24                                  Rotlaust Tre Fell  0hjczqsEDgNhPTd8JLUlbq
# 25                                           Tallulah  3G80CgLA7ziD8i40s6uKQN
# 26                                     I Have a Right  2f2fhCBYIRSeV7dDuxSdT1
# 27                                           Fullmoon  5zDYy3XRelHRS8swl2o3DK
# 28                                    Last Drop Falls  4bSetRYOPYAMlLc9mgEGr0
# 29                                                Shy  4Ym23Bf7Kv2aZLqkq7mIrb
#
#                    track_artist                   added_by  \
# 0          American Murder Song  yaojxcyh5tczzlln0ygm9sfla
# 1          American Murder Song  yaojxcyh5tczzlln0ygm9sfla
# 2          American Murder Song  yaojxcyh5tczzlln0ygm9sfla
# 3            Circus Contraption  yaojxcyh5tczzlln0ygm9sfla
# 4   The Circus Contraption Band  yaojxcyh5tczzlln0ygm9sfla
# 5   The Circus Contraption Band  yaojxcyh5tczzlln0ygm9sfla
# 6                  Katzenjammer  yaojxcyh5tczzlln0ygm9sfla
# 7                  Katzenjammer  yaojxcyh5tczzlln0ygm9sfla
# 8                  Katzenjammer  yaojxcyh5tczzlln0ygm9sfla
# 9                     Van Canto  yaojxcyh5tczzlln0ygm9sfla
# 10                    Van Canto  yaojxcyh5tczzlln0ygm9sfla
# 11                    Van Canto  yaojxcyh5tczzlln0ygm9sfla
# 12              The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 13              The Cog is Dead  yaojxcyh5tczzlln0ygm9sfla
# 14              The Cog is Dead  yaojxcyh5tczzlln0ygm9sfla
# 15                Emilie Autumn  yaojxcyh5tczzlln0ygm9sfla
# 16                Emilie Autumn  yaojxcyh5tczzlln0ygm9sfla
# 17                Emilie Autumn  yaojxcyh5tczzlln0ygm9sfla
# 18            The Dresden Dolls  yaojxcyh5tczzlln0ygm9sfla
# 19            The Dresden Dolls  yaojxcyh5tczzlln0ygm9sfla
# 20            The Dresden Dolls  yaojxcyh5tczzlln0ygm9sfla
# 21                    Stan Bush  yaojxcyh5tczzlln0ygm9sfla
# 22                 Jake Edwards  yaojxcyh5tczzlln0ygm9sfla
# 23                 Jake Edwards  yaojxcyh5tczzlln0ygm9sfla
# 24                    The Cliks  yaojxcyh5tczzlln0ygm9sfla
# 25                    The Cliks  yaojxcyh5tczzlln0ygm9sfla
# 26                Kirby Krackle  yaojxcyh5tczzlln0ygm9sfla
# 27                Kirby Krackle  yaojxcyh5tczzlln0ygm9sfla
# 28                     Worriers  yaojxcyh5tczzlln0ygm9sfla
# 29                    The Cliks  yaojxcyh5tczzlln0ygm9sfla
# 30          Dog Park Dissidents  yaojxcyh5tczzlln0ygm9sfla
# 31                     Skindred  yaojxcyh5tczzlln0ygm9sfla
# 32                     Skindred  yaojxcyh5tczzlln0ygm9sfla
# 33                     Skindred  yaojxcyh5tczzlln0ygm9sfla
# 34                 Gaelic Storm  yaojxcyh5tczzlln0ygm9sfla
# 35                 Gaelic Storm  yaojxcyh5tczzlln0ygm9sfla
# 36                Great Big Sea  yaojxcyh5tczzlln0ygm9sfla
# 37                    Brand New  yaojxcyh5tczzlln0ygm9sfla
# 38                         Ludo  yaojxcyh5tczzlln0ygm9sfla
# 39                         Ludo  yaojxcyh5tczzlln0ygm9sfla
# 40                 The Protomen  yaojxcyh5tczzlln0ygm9sfla
# 41                 The Protomen  yaojxcyh5tczzlln0ygm9sfla
# 42                 The Protomen  yaojxcyh5tczzlln0ygm9sfla
# 43       This Way To The Egress  yaojxcyh5tczzlln0ygm9sfla
# 44       This Way To The Egress  yaojxcyh5tczzlln0ygm9sfla
# 45       This Way To The Egress  yaojxcyh5tczzlln0ygm9sfla
# 46                         TOOL  yaojxcyh5tczzlln0ygm9sfla
# 47                         TOOL  yaojxcyh5tczzlln0ygm9sfla
# 48                         TOOL  yaojxcyh5tczzlln0ygm9sfla
# 49                       OOMPH!  yaojxcyh5tczzlln0ygm9sfla
# 50                    Halestorm  yaojxcyh5tczzlln0ygm9sfla
# 51                         Otep  yaojxcyh5tczzlln0ygm9sfla
# 52    CoCo and The Butterfields  yaojxcyh5tczzlln0ygm9sfla
# 53    CoCo and The Butterfields  yaojxcyh5tczzlln0ygm9sfla
# 54           A Sound of Thunder  yaojxcyh5tczzlln0ygm9sfla
# 55           A Sound of Thunder  yaojxcyh5tczzlln0ygm9sfla
# 56               Jonathan Young  yaojxcyh5tczzlln0ygm9sfla
# 57               Jonathan Young  yaojxcyh5tczzlln0ygm9sfla
# 58                     Puscifer  yaojxcyh5tczzlln0ygm9sfla
# 59                  Bitter Ruin  yaojxcyh5tczzlln0ygm9sfla
# 60                  Bitter Ruin  yaojxcyh5tczzlln0ygm9sfla
# 61             Dirt Poor Robins  yaojxcyh5tczzlln0ygm9sfla
# 62                  Caleb Hyles  yaojxcyh5tczzlln0ygm9sfla
# 63       Air Traffic Controller  yaojxcyh5tczzlln0ygm9sfla
# 64                    AlicebanD  yaojxcyh5tczzlln0ygm9sfla
# 65     The Jane Austen Argument  yaojxcyh5tczzlln0ygm9sfla
# 66     The Jane Austen Argument  yaojxcyh5tczzlln0ygm9sfla
# 67     The Jane Austen Argument  yaojxcyh5tczzlln0ygm9sfla
# 68             Miracle Of Sound  yaojxcyh5tczzlln0ygm9sfla
# 69             Miracle Of Sound  yaojxcyh5tczzlln0ygm9sfla
# 70            Blackmore's Night  yaojxcyh5tczzlln0ygm9sfla
# 71            Blackmore's Night  yaojxcyh5tczzlln0ygm9sfla
# 72               The Mechanisms  yaojxcyh5tczzlln0ygm9sfla
# 73               The Mechanisms  yaojxcyh5tczzlln0ygm9sfla
# 74                     Tub Ring  yaojxcyh5tczzlln0ygm9sfla
# 75         The Orion Experience  yaojxcyh5tczzlln0ygm9sfla
# 76             Terrance Zdunich  yaojxcyh5tczzlln0ygm9sfla
# 77                     JT Music  yaojxcyh5tczzlln0ygm9sfla
# 78                Shayfer James  yaojxcyh5tczzlln0ygm9sfla
# 79                Shayfer James  yaojxcyh5tczzlln0ygm9sfla
# 80                Shayfer James  yaojxcyh5tczzlln0ygm9sfla
# 81               The Mechanisms  yaojxcyh5tczzlln0ygm9sfla
# 82                  The Weepies  yaojxcyh5tczzlln0ygm9sfla
# 83                  The Weepies  yaojxcyh5tczzlln0ygm9sfla
# 84                  The Weepies  yaojxcyh5tczzlln0ygm9sfla
# 85                  The Weepies  yaojxcyh5tczzlln0ygm9sfla
# 86              Captain Tractor  yaojxcyh5tczzlln0ygm9sfla
# 0                     Fever Ray  yaojxcyh5tczzlln0ygm9sfla
# 1                     Fever Ray  yaojxcyh5tczzlln0ygm9sfla
# 2                     Fever Ray  yaojxcyh5tczzlln0ygm9sfla
# 3                     Fever Ray  yaojxcyh5tczzlln0ygm9sfla
# 4                  The Traveler  yaojxcyh5tczzlln0ygm9sfla
# 5                  The Traveler  yaojxcyh5tczzlln0ygm9sfla
# 6                  The Traveler  yaojxcyh5tczzlln0ygm9sfla
# 7                  The Traveler  yaojxcyh5tczzlln0ygm9sfla
# 8                  The Traveler  yaojxcyh5tczzlln0ygm9sfla
# 9               The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 10              The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 11              The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 12              The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 13              The Dear Hunter  yaojxcyh5tczzlln0ygm9sfla
# 14                     Alestorm  yaojxcyh5tczzlln0ygm9sfla
# 15                     Alestorm  yaojxcyh5tczzlln0ygm9sfla
# 16                     Alestorm  yaojxcyh5tczzlln0ygm9sfla
# 17                     Alestorm  yaojxcyh5tczzlln0ygm9sfla
# 18                     Alestorm  yaojxcyh5tczzlln0ygm9sfla
# 19                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 20                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 21                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 22                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 23                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 24                     Wardruna  yaojxcyh5tczzlln0ygm9sfla
# 25               Sonata Arctica  yaojxcyh5tczzlln0ygm9sfla
# 26               Sonata Arctica  yaojxcyh5tczzlln0ygm9sfla
# 27               Sonata Arctica  yaojxcyh5tczzlln0ygm9sfla
# 28               Sonata Arctica  yaojxcyh5tczzlln0ygm9sfla
# 29               Sonata Arctica  yaojxcyh5tczzlln0ygm9sfla
#
#                 added_at  danceability  energy  key  ...  liveness  valence  \
# 0   2020-11-23T20:42:14Z         0.704   0.690    5  ...    0.6310   0.4920
# 1   2020-11-23T20:42:45Z         0.633   0.755    4  ...    0.3090   0.6960
# 2   2020-11-23T20:42:59Z         0.805   0.850    7  ...    0.0673   0.8220
# 3   2020-11-23T20:43:15Z         0.517   0.633    9  ...    0.1120   0.9630
# 4   2020-11-23T20:43:23Z         0.617   0.572    5  ...    0.1890   0.4530
# 5   2020-11-23T20:43:28Z         0.568   0.564    2  ...    0.0916   0.5910
# 6   2020-11-23T20:43:39Z         0.589   0.799    7  ...    0.3700   0.7130
# 7   2020-11-23T20:43:45Z         0.463   0.776    5  ...    0.0633   0.8760
# 8   2020-11-23T20:43:49Z         0.392   0.394    1  ...    0.1440   0.1210
# 9   2020-11-23T20:44:14Z         0.321   0.940    4  ...    0.1770   0.2550
# 10  2020-11-23T20:44:30Z         0.438   0.953   11  ...    0.2790   0.3810
# 11  2020-11-23T20:44:35Z         0.492   0.923    9  ...    0.1090   0.8130
# 12  2020-11-23T20:45:05Z         0.591   0.818    9  ...    0.1040   0.6050
# 13  2020-11-23T20:45:29Z         0.417   0.436    0  ...    0.0550   0.6150
# 14  2020-11-23T20:45:33Z         0.674   0.803    9  ...    0.0632   0.5250
# 15  2020-11-23T20:45:46Z         0.626   0.729    0  ...    0.5600   0.3420
# 16  2020-11-23T20:45:50Z         0.608   0.564    2  ...    0.3060   0.7090
# 17  2020-11-23T20:45:58Z         0.567   0.870    1  ...    0.0860   0.4250
# 18  2020-11-23T20:46:07Z         0.416   0.883   10  ...    0.1100   0.7880
# 19  2020-11-23T20:46:10Z         0.631   0.455    7  ...    0.0480   0.5430
# 20  2020-11-23T20:46:15Z         0.680   0.168    7  ...    0.2830   0.1790
# 21  2020-11-23T20:46:33Z         0.594   0.919    2  ...    0.1780   0.5290
# 22  2020-11-23T20:47:02Z         0.476   0.698    5  ...    0.1320   0.2560
# 23  2020-11-23T20:47:08Z         0.471   0.361   11  ...    0.0916   0.7120
# 24  2020-11-23T20:47:20Z         0.538   0.879    0  ...    0.1760   0.8850
# 25  2020-11-23T20:47:36Z         0.633   0.677   11  ...    0.0639   0.5610
# 26  2020-11-23T20:47:51Z         0.562   0.826    5  ...    0.0942   0.6230
# 27  2020-11-23T20:47:55Z         0.581   0.913    6  ...    0.3330   0.7510
# 28  2020-11-23T20:48:43Z         0.388   0.933    2  ...    0.3250   0.6350
# 29  2020-11-23T20:49:02Z         0.590   0.686    7  ...    0.0867   0.4080
# 30  2020-11-23T20:49:13Z         0.444   0.946    1  ...    0.6210   0.1560
# 31  2020-11-23T20:49:31Z         0.632   0.979    0  ...    0.3730   0.8150
# 32  2020-11-23T20:49:42Z         0.402   0.989    1  ...    0.3550   0.4740
# 33  2020-11-23T20:49:49Z         0.642   0.985    1  ...    0.2740   0.5710
# 34  2020-11-23T20:50:23Z         0.589   0.875    0  ...    0.0354   0.9630
# 35  2020-11-23T20:50:32Z         0.457   0.716    0  ...    0.0731   0.2320
# 36  2020-11-23T20:50:39Z         0.827   0.446    6  ...    0.0891   0.7320
# 37  2020-11-23T20:50:46Z         0.508   0.757    8  ...    0.1180   0.4230
# 38  2020-11-23T20:51:11Z         0.598   0.794    2  ...    0.0794   0.3730
# 39  2020-11-23T20:51:24Z         0.651   0.869    0  ...    0.3660   0.7240
# 40  2020-11-23T20:52:03Z         0.508   0.892    1  ...    0.3520   0.2700
# 27  2020-09-23T20:39:50Z         0.486   0.937    6  ...    0.0977   0.2600
# 28  2020-09-23T20:39:53Z         0.444   0.645    3  ...    0.1110   0.1500
# 29  2020-09-23T20:39:57Z         0.378   0.223    3  ...    0.1100   0.1500
#
#       tempo            type                      id  \
# 0   111.935  audio_features  2z2rcCzS0jBTya2SwQZIpW
# 1    75.041  audio_features  6jfV9Y5nVFRzcHCxRgaGMC
# 2   126.020  audio_features  0Rx4vXgplon2ozMhds93V1
# 3   165.285  audio_features  4k9fR7zBEvwyN9j0GUEYbg
# 4   111.091  audio_features  0Jkl79sElTWQnUr534STeJ
# 5   106.535  audio_features  5KUqeG9pyDA2YgI2o4YIwm
# 6   143.954  audio_features  0ytvlQNCJmSY6l6a840U5A
# 7   184.420  audio_features  5AErfeSAv0NPSivHpe12AU
# 8    76.450  audio_features  46Cec5dxngueMCy0IBO3YJ
# 9   112.506  audio_features  3NvI1qSyQoFlsXg97jVVNM
# 10  174.009  audio_features  3pKrxpx71RK0MFoCg1l2Ew
# 11  170.075  audio_features  4PdrfzPj5D48xykbhLOHP7
# 12  104.960  audio_features  4KOxCZLwedKjCJlZzr3M9R
# 13  172.113  audio_features  3SokYcSBJpLmPt3HH6b2uE
# 14   90.035  audio_features  4Fz63h1gjK9xVB47Na4CaJ
# 15  150.107  audio_features  4V93gGmV1qZUQLsixwNywF
# 16  142.446  audio_features  5hNpgLjnZpnaDNhwKWjjhm
# 17  145.020  audio_features  1qKYsw98bcjTi07r23Zzlm
# 18  178.330  audio_features  6Zbv79YWB0iZSXwIwEsIOP
# 19  134.772  audio_features  2OcJNw7K8cYs4FKoh8aEow
# 20   74.630  audio_features  2BK4RO4S66gu7Nb8LF4ANc
# 21  126.570  audio_features  2QyGSbGdT9suKuDKwnjwH9
# 22  112.959  audio_features  1MH7afub7lFfO6XiTbXJNd
# 23   97.507  audio_features  0hPwLyW9MaXVRMEtLNn78q
# 24  146.058  audio_features  4gLaLu81eTycFJgTjvuhC2
# 25  138.059  audio_features  08bgaYICwxNPb8gRyp08iX
# 26   91.011  audio_features  1AcPyhicH1Ev99zxYXLOBY
# 27  136.060  audio_features  4z8eKCqV89vlVq8i88wyNZ
# 28   89.924  audio_features  5zpUjhFZWLZ7vCVk6ZpnRs
# 29  129.969  audio_features  5ZNrgIRxbCk1ehb5cSxtSb
# 30  179.966  audio_features  0LKE84p5RWSk6LtJOQ0srS
# 31  107.018  audio_features  6ZQTarcEfQOgkNAmI5dCdA
# 32  191.200  audio_features  5kq6IIgzpp9PlmbA7fGmPF
# 33  109.997  audio_features  1CiSFemWkynkGNdGaB3ITJ
# 34  155.082  audio_features  7ckwjcZb62QhOtCxIhKB7B
# 35  143.912  audio_features  153EejT5BPgiyvRtx60vSa
# 36  112.033  audio_features  1wf9F3L1B11i9WTfvwnfMo
# 37   91.344  audio_features  4V0he7zYfJLEjfCDfojToB
# 38  120.917  audio_features  3IlYkyctlcTqXAZOA4ZPzz
# 39  119.995  audio_features  1vVth79syfh5YQwa8DmiMP
# 40   83.970  audio_features  0b4KsOdnrZlfE5VUAAzxv1
# 41  103.812  audio_features  4GwNeCsNlcnxtss75iWnDY
# 42  150.221  audio_features  0H4CZtqWkgELMfWIfSAUE9
# 43  131.034  audio_features  7nFqCt94yQ7rdu8wHWSNaw
# 44   97.179  audio_features  1hrTbdDgxlNDXm7EdfqYT1
# 45  129.234  audio_features  1QE6L6rAYxHxCgg9pM9F9k
# 46  159.230  audio_features  6AioOohg4bQZFA4jIYQQ2r
# 47  149.271  audio_features  6DyywdbmTzlmXBzG9ym7Rt
# 48  110.420  audio_features  2gbPu2QNqhnnqtfK3yyeZ0
# 49  130.013  audio_features  4n3d7D78ltmhcebtZ18YbZ
# 50  137.868  audio_features  0dnx2LK0rnPTACGzbLc1Jx
# 51   77.507  audio_features  0juWU6pPyAV3wbkrNkWo8X
# 52  147.082  audio_features  6jdeRcEqrysWtOTxyAfFgx
# 53   80.022  audio_features  2kTalsZJh5SJZZwMkkWUrQ
# 54   85.083  audio_features  0ZAL9WOD5U37Vf6X9Nlr21
# 55  101.022  audio_features  4J3qJ1GgDILlL9zKZp8nSm
# 56  138.855  audio_features  3gdkpaNko3WvVedIaAQkOe
# 57  122.069  audio_features  1HKmRfUBFGGc44nntsy5dt
# 58  144.111  audio_features  2t3ezqieuK6RRav66q9bQF
# 59  124.868  audio_features  74cnDHEuyhzDYbtZfCJsWe
# 60  134.836  audio_features  15AU0acyia6nQ6ovin3tkV
# 61   94.014  audio_features  06OTh3RF2IIBukgVHkrNDv
# 62  149.119  audio_features  1jwB0gUGOV3hjehkGbVtJe
# 63  112.067  audio_features  2cls4groLeYT1zmlXN1pO2
# 64  125.270  audio_features  1ehzWR9ScnFF1PsCPiCubN
# 65  179.516  audio_features  64PO3Y28NRwBWynS1dyFJk
# 66  164.962  audio_features  4b6xOSixXfniyQIOBlSic3
# 67   96.327  audio_features  3hPb8ma3IpaWVtCxvHzPEn
# 68  159.170  audio_features  0clLkj1AMdB66TpLHZnazR
# 69  114.976  audio_features  7FSgUdEyYap0Wbix3tKWPp
# 70  114.967  audio_features  2E1QXihcO7wNK0P7mipkKc
# 71   81.990  audio_features  7pDDVJQZIg0PLVUzAT0KGj
# 72  104.980  audio_features  4bBYnFFtAGW569knGZULiV
# 73  132.055  audio_features  6t9dD15CXgI1FMGtP2uli0
# 74  119.991  audio_features  7eNPLy3AXyy0IEAFIrTiyR
# 75  137.498  audio_features  4zg2zMNSI0W8ipGA32kKp5
# 76  115.786  audio_features  72p0iFeYYSCulZ3kRs5l5p
# 77  135.010  audio_features  2WbOHt3obXTYx6RdJmAJSV
# 78   95.029  audio_features  4SiGXrytSA6LQAZOcowwPF
# 79  137.971  audio_features  6EIGwiu6sFLL64Fs67JVIj
# 80   82.020  audio_features  3mBzmGcvEytNUsPHmpqtXZ
# 81  134.054  audio_features  2XZHL0Lst5dUViEBjXECbM
# 82  107.612  audio_features  0bAM9qivrntXnHyklRRx39
# 83   75.004  audio_features  0YNNfiKJb4yqUDtCcX1cHK
# 84  143.975  audio_features  5jbykCJt1yGovDZtPUaRug
# 85   86.007  audio_features  3hvdd5IO8VfD038KnOO3o2
# 86  123.935  audio_features  2DA5mJBf88xooCYWPXMxNN
# 0   170.103  audio_features  1we2UifyzGe2tgvTVFTwD4
# 1   157.989  audio_features  3TbKcmraxp8J4PvsJNRXhi
# 2   109.994  audio_features  3S2yvrjwH1hruVD4UWDapM
# 3   117.004  audio_features  5bhgC6aNOJIt5PVTrmuwu1
# 4    86.020  audio_features  5dTzngZpvdeq7mNLFD4rsK
# 5   103.706  audio_features  6lKvs8U3FgKdAGc2TaPegC
# 6    92.960  audio_features  5x7c7u6ysrLX38mW9DoOm2
# 7    88.970  audio_features  0W4ROoDO76CQNHydpm4Nyq
# 8   157.034  audio_features  0G3KqFAaHsQ261MZzScp3I
# 9   164.842  audio_features  1A4T3cm5mteRN0nz4AiY7P
# 10  104.960  audio_features  4KOxCZLwedKjCJlZzr3M9R
# 11  140.016  audio_features  3ho676UrO1qCIY0gKHs8kN
# 12  149.967  audio_features  3ig2dV1bPM5ejNjd0iOp9U
# 13  188.383  audio_features  5nVjujWglwDnhlAjXFNsdI
# 14  160.051  audio_features  5Hzto0vLxLb8GfkUtu6ZJK
# 15   76.964  audio_features  2dgex0FiYtsHguA8D5WScn
# 16  110.057  audio_features  6pKA3P1JERZutikZtZpoUo
# 17  128.009  audio_features  35cnc4XqirI3CzVMIaQQWP
# 18   75.000  audio_features  1hiaLyqpVlJSSlaWNl22Hb
# 19  100.670  audio_features  1bqmaIBGwlo4MtrAxjRDHB
# 20  105.022  audio_features  528KWNngYORvUkoixWpqqy
# 21   80.983  audio_features  5iRCFYfU71YToV9UssimKe
# 22  124.805  audio_features  01pGPwb1OkC5JflWmcqeYQ
# 23  124.805  audio_features  01pGPwb1OkC5JflWmcqeYQ
# 24   65.004  audio_features  0hjczqsEDgNhPTd8JLUlbq
# 25  139.701  audio_features  3G80CgLA7ziD8i40s6uKQN
# 26   79.951  audio_features  2f2fhCBYIRSeV7dDuxSdT1
# 27  158.964  audio_features  5zDYy3XRelHRS8swl2o3DK
# 28  127.853  audio_features  4bSetRYOPYAMlLc9mgEGr0
# 29   79.980  audio_features  4Ym23Bf7Kv2aZLqkq7mIrb
#
#                                      uri  \
# 0   spotify:track:2z2rcCzS0jBTya2SwQZIpW
# 1   spotify:track:6jfV9Y5nVFRzcHCxRgaGMC
# 2   spotify:track:0Rx4vXgplon2ozMhds93V1
# 3   spotify:track:4k9fR7zBEvwyN9j0GUEYbg
# 4   spotify:track:0Jkl79sElTWQnUr534STeJ
# 5   spotify:track:5KUqeG9pyDA2YgI2o4YIwm
# 6   spotify:track:0ytvlQNCJmSY6l6a840U5A
# 7   spotify:track:5AErfeSAv0NPSivHpe12AU
# 8   spotify:track:46Cec5dxngueMCy0IBO3YJ
# 9   spotify:track:3NvI1qSyQoFlsXg97jVVNM
# 7   https://api.spotify.com/v1/audio-analysis/5AEr...      208720
# 8   https://api.spotify.com/v1/audio-analysis/46Ce...      251947
# 9   https://api.spotify.com/v1/audio-analysis/3NvI...      429387
# 10  https://api.spotify.com/v1/audio-analysis/3pKr...      254867
# 11  https://api.spotify.com/v1/audio-analysis/4Pdr...      218267
# 12  https://api.spotify.com/v1/audio-analysis/4KOx...      195960
# 13  https://api.spotify.com/v1/audio-analysis/3Sok...      158225
# 14  https://api.spotify.com/v1/audio-analysis/4Fz6...      192848
# 15  https://api.spotify.com/v1/audio-analysis/4V93...      323920
# 16  https://api.spotify.com/v1/audio-analysis/5hNp...      373533
# 17  https://api.spotify.com/v1/audio-analysis/1qKY...      242493
# 18  https://api.spotify.com/v1/audio-analysis/6Zbv...      179467
# 19  https://api.spotify.com/v1/audio-analysis/2OcJ...      286413
# 20  https://api.spotify.com/v1/audio-analysis/2BK4...      293147
# 21  https://api.spotify.com/v1/audio-analysis/2QyG...      236560
# 22  https://api.spotify.com/v1/audio-analysis/1MH7...      267173
# 23  https://api.spotify.com/v1/audio-analysis/0hPw...      144973
# 24  https://api.spotify.com/v1/audio-analysis/4gLa...      223842
# 25  https://api.spotify.com/v1/audio-analysis/08bg...      275307
# 26  https://api.spotify.com/v1/audio-analysis/1AcP...      271093
# 27  https://api.spotify.com/v1/audio-analysis/4z8e...      199653
# 28  https://api.spotify.com/v1/audio-analysis/5zpU...      138824
# 29  https://api.spotify.com/v1/audio-analysis/5ZNr...      233535
# 30  https://api.spotify.com/v1/audio-analysis/0LKE...      128000
# 31  https://api.spotify.com/v1/audio-analysis/6ZQT...      201267
# 32  https://api.spotify.com/v1/audio-analysis/5kq6...      181560
# 33  https://api.spotify.com/v1/audio-analysis/1CiS...      222640
# 34  https://api.spotify.com/v1/audio-analysis/7ckw...      233600
# 35  https://api.spotify.com/v1/audio-analysis/153E...      206400
# 36  https://api.spotify.com/v1/audio-analysis/1wf9...      156267
# 37  https://api.spotify.com/v1/audio-analysis/4V0h...      213640
# 38  https://api.spotify.com/v1/audio-analysis/3IlY...      260533
# 39  https://api.spotify.com/v1/audio-analysis/1vVt...      176280
# 40  https://api.spotify.com/v1/audio-analysis/0b4K...      244227
# 41  https://api.spotify.com/v1/audio-analysis/4GwN...      271133
# 42  https://api.spotify.com/v1/audio-analysis/0H4C...      249507
# 43  https://api.spotify.com/v1/audio-analysis/7nFq...      264400
# 44  https://api.spotify.com/v1/audio-analysis/1hrT...      220864
# 45  https://api.spotify.com/v1/audio-analysis/1QE6...      248370
# 46  https://api.spotify.com/v1/audio-analysis/6Aio...      363067
# 47  https://api.spotify.com/v1/audio-analysis/6Dyy...      306853
# 48  https://api.spotify.com/v1/audio-analysis/2gbP...      448613
# 49  https://api.spotify.com/v1/audio-analysis/4n3d...      202240
# 50  https://api.spotify.com/v1/audio-analysis/0dnx...      202307
# 51  https://api.spotify.com/v1/audio-analysis/0juW...      323227
# 52  https://api.spotify.com/v1/audio-analysis/6jde...      224414
# 53  https://api.spotify.com/v1/audio-analysis/2kTa...      229160
# 54  https://api.spotify.com/v1/audio-analysis/0ZAL...      337733
# 55  https://api.spotify.com/v1/audio-analysis/4J3q...      274253
# 56  https://api.spotify.com/v1/audio-analysis/3gdk...      311990
# 57  https://api.spotify.com/v1/audio-analysis/1HKm...      227490
# 58  https://api.spotify.com/v1/audio-analysis/2t3e...      305520
# 59  https://api.spotify.com/v1/audio-analysis/74cn...      185200
# 60  https://api.spotify.com/v1/audio-analysis/15AU...      226101
# 61  https://api.spotify.com/v1/audio-analysis/06OT...      228235
# 62  https://api.spotify.com/v1/audio-analysis/1jwB...      314911
# 63  https://api.spotify.com/v1/audio-analysis/2cls...      163453
# 64  https://api.spotify.com/v1/audio-analysis/1ehz...      191472
# 65  https://api.spotify.com/v1/audio-analysis/64PO...      243000
# 66  https://api.spotify.com/v1/audio-analysis/4b6x...      275040
# 67  https://api.spotify.com/v1/audio-analysis/3hPb...      204907
# 68  https://api.spotify.com/v1/audio-analysis/0clL...      226659
# 69  https://api.spotify.com/v1/audio-analysis/7FSg...      160297
# 70  https://api.spotify.com/v1/audio-analysis/2E1Q...      216280
# 71  https://api.spotify.com/v1/audio-analysis/7pDD...      345333
# 72  https://api.spotify.com/v1/audio-analysis/4bBY...      254080
# 73  https://api.spotify.com/v1/audio-analysis/6t9d...      231567
# 74  https://api.spotify.com/v1/audio-analysis/7eNP...      128592
# 75  https://api.spotify.com/v1/audio-analysis/4zg2...      185307
# 76  https://api.spotify.com/v1/audio-analysis/72p0...      221587
# 77  https://api.spotify.com/v1/audio-analysis/2WbO...      313333
# 78  https://api.spotify.com/v1/audio-analysis/4SiG...      221480
# 79  https://api.spotify.com/v1/audio-analysis/6EIG...      201560
# 80  https://api.spotify.com/v1/audio-analysis/3mBz...      193467
# 81  https://api.spotify.com/v1/audio-analysis/2XZH...      206131
# 82  https://api.spotify.com/v1/audio-analysis/0bAM...      165133
# 83  https://api.spotify.com/v1/audio-analysis/0YNN...      199787
# 84  https://api.spotify.com/v1/audio-analysis/5jby...      199533
# 85  https://api.spotify.com/v1/audio-analysis/3hvd...      175587
# 86  https://api.spotify.com/v1/audio-analysis/2DA5...      386867
# 0   https://api.spotify.com/v1/audio-analysis/1we2...      227494
# 1   https://api.spotify.com/v1/audio-analysis/3TbK...      339707
# 2   https://api.spotify.com/v1/audio-analysis/3S2y...      279340
# 3   https://api.spotify.com/v1/audio-analysis/5bhg...      268536
# 4   https://api.spotify.com/v1/audio-analysis/5dTz...       95556
# 5   https://api.spotify.com/v1/audio-analysis/6lKv...      154540
# 6   https://api.spotify.com/v1/audio-analysis/5x7c...      107233
# 7   https://api.spotify.com/v1/audio-analysis/0W4R...      193384
# 8   https://api.spotify.com/v1/audio-analysis/0G3K...      136385
# 9   https://api.spotify.com/v1/audio-analysis/1A4T...      240613
# 10  https://api.spotify.com/v1/audio-analysis/4KOx...      195960
# 11  https://api.spotify.com/v1/audio-analysis/3ho6...      367333
# 12  https://api.spotify.com/v1/audio-analysis/3ig2...      252493
# 13  https://api.spotify.com/v1/audio-analysis/5nVj...      540184
# 14  https://api.spotify.com/v1/audio-analysis/5Hzt...      202587
# 15  https://api.spotify.com/v1/audio-analysis/2dge...      207493
# 16  https://api.spotify.com/v1/audio-analysis/6pKA...      222253
# 17  https://api.spotify.com/v1/audio-analysis/35cn...      190333
# 18  https://api.spotify.com/v1/audio-analysis/1hia...      256389
# 19  https://api.spotify.com/v1/audio-analysis/1bqm...      431867
# 20  https://api.spotify.com/v1/audio-analysis/528K...      405280
# 21  https://api.spotify.com/v1/audio-analysis/5iRC...      507456
# 22  https://api.spotify.com/v1/audio-analysis/01pG...      390373
# 23  https://api.spotify.com/v1/audio-analysis/01pG...      390373
# 24  https://api.spotify.com/v1/audio-analysis/0hjc...      251653
# 25  https://api.spotify.com/v1/audio-analysis/3G80...      320467
# 26  https://api.spotify.com/v1/audio-analysis/2f2f...      287960
# 27  https://api.spotify.com/v1/audio-analysis/5zDY...      312053
# 28  https://api.spotify.com/v1/audio-analysis/4bSe...      313533
# 29  https://api.spotify.com/v1/audio-analysis/4Ym2...      255787
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               1
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              3
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
# 20              4
# 21              4
# 22              4
# 23              4
# 24              4
# 25              4
# 26              4
# 27              3
# 28              4
# 29              4
# 30              4
# 31              4
# 32              4
# 33              4
# 34              4
# 35              4
# 36              4
# 37              4
# 38              4
# 39              4
# 40              4
# 41              4
# 42              4
# 43              4
# 44              4
# 45              4
# 46              4
# 47              4
# 48              3
# 49              4
# 50              4
# 51              4
# 52              4
# 53              4
# 54              4
# 55              4
# 56              4
# 57              4
# 58              4
# 59              4
# 60              4
# 61              4
# 62              3
# 63              4
# 64              4
# 65              3
# 66              3
# 67              3
# 68              4
# 69              4
# 70              4
# 71              3
# 72              3
# 73              4
# 74              4
# 75              4
# 76              4
# 77              4
# 78              4
# 79              4
# 80              4
# 81              4
# 82              4
# 83              5
# 84              4
# 85              4
# 86              4
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               3
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              3
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4
# 20              5
# 21              4
# 22              4
# 23              4
# 24              4
# 25              4
# 26              4
# 27              4
# 28              4
# 29              4
#
# [117 rows x 25 columns]

# %%
cassie_acct.

# %%
test_df = ben_acct.personal_playlists[0:2]

# %%
ben_acct.personal_playlists[0:2]

# %%
ben_acct.playlists

# %%
cassie_acct.personal_playlists['num_tracks'].sum()

# %%
ben_acct.personal_playlists['num_tracks'].sum()

# %%
collab_filter = (ben_acct.playlists['collaborative'] == True) & (ben_acct.playlists['owner_name'] != self.name)
personal_filter = ben_acct.playlists['owner_name'] == self.name

# %%
ben_acct.name

# %%
import timeit

# %%
start = timeit.default_timer()
xx = ben_acct.get_all_playlist_tracks(ben_acct.personal_playlists[0:2])
end = timeit.default_timer()
diff = end - start
print(f'Timer: {diff} sec for {len(xx)} entries')

# %%
ben_acct.playlists

# %%
ben_acct.id, ben_acct.name
