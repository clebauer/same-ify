# %%
#!pip install pandas matplotlib seaborn spotipy

# %%
# ********** Import Statements ************************************************************ #
import sys
import spotipy
import spotipy.util as util

import pandas as pd
import math

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', 500)

# %%
# Spotify user IDs for testing: these are public information.
user_ids = {'Cassie':'1242091675',
            'Caity':'12166088827',
            'Ben':'yaojxcyh5tczzlln0ygm9sfla',
            'Alex':'12130992491',
            'Jason':'jason.albert'}

# %%
class Sameify:
    
    def __init__(self, user_id):
        self.id = user_id
        # Connect to Spotify
        self.sp = self.spotify_connect()
        self.playlists = self.get_all_playlists() 
        #self.playlist_tracks = self.get_all_playlist_tracks(self.playlists['playlist_id'][0])
        
        
    # Spotify credentials
    scope = 'playlist-modify-public user-library-read user-read-recently-played'
    #client_id removed
    #client_secret removed
    redirect_uri = 'http://localhost:8889/'

    # Connects to Spotify
    def spotify_connect(self):
        token = util.prompt_for_user_token(self.id,
                                           self.scope,
                                           self.client_id,
                                           self.client_secret,
                                           self.redirect_uri)

        sp = spotipy.Spotify(auth=token)
        return sp
    
    #def overstep_limit(self, item_id):

    def get_playlist_id(self, playlist_name):
        return self.playlists.loc[self.playlists['playlist_name'] == playlist_name,'playlist_id'].values[0]
    
    def get_playlist_name(self, playlist_id):
        return self.playlists.loc[self.playlists['playlist_id'] == playlist_id,'playlist_name'].values[0]
    
    def playlist_tracks(self, playlist_id):
        ret_df = pd.DataFrame()
        
        playlist = self.sp.user_playlist_tracks(self.id, playlist_id)
        playlist_name = self.get_playlist_name(playlist_id)
        tracks = playlist['items']
        
        while playlist['next']:
            playlist = self.sp.next(playlist)
            tracks.extend(playlist['items'])
            
        for track in tracks:
            x = track['track']
            data = {'playlist_id'  : playlist_id,
                    'playlist_name': playlist_name,
                    'track_name'   : x['name'],
                    'track_id'     : x['id'], 
                    'track_artist_id' : x['artists'][0]['id'],
                    'track_artist' : x['artists'][0]['name'], #[artist['name'] for artist in x['artists']]
                    'added_by'     : track['added_by']['id'],
                    'added_at'     : track['added_at']
                   }
            data_df = pd.DataFrame([data])
            song_deets = pd.DataFrame(self.sp.audio_features(data['track_id']))
            
            full_data = pd.concat([data_df, song_deets],axis=1)
            
            ret_df = ret_df.append(full_data)
        ret_df.reset_index(drop=True, inplace=True)
        return ret_df
            
#     def get_all_recently_played(self):
#         tracks = pd.DataFrame()
        
#         total = self.sp.user_playlists(self.id)['total'] #number of playlists
#         limit = 50 # pull at a time
        
#         for x in range(0, total, limit): # for each set of playlists
#             new_playlist = self.sp.user_playlists(self.id, limit=limit, offset=x)
#             for x in new_playlist['items']:
#                 items = {'playlist_name': x['name'],
#                          'playlist_id'  : x['id'],
#                          'owner_name'   : x['owner']['display_name'],
#                          'owner_id'     : x['owner']['id'],
#                          'num_tracks'   : x['tracks']['total'],
#                          'collaborative': x['collaborative'],
                         
                         
#         Cassie.sp.current_user_recently_played()

    def get_all_playlists(self):
        playlists = pd.DataFrame()
        
        total = self.sp.user_playlists(self.id)['total'] #number of playlists
        limit = 50 # pull at a time
        
        for x in range(0, total, limit): # for each set of playlists
            new_playlist = self.sp.user_playlists(self.id, limit=limit, offset=x)
            for x in new_playlist['items']:
                items = {'playlist_name': x['name'],
                         'playlist_id'  : x['id'],
                         'owner_name'   : x['owner']['display_name'],
                         'owner_id'     : x['owner']['id'],
                         'num_tracks'   : x['tracks']['total'],
                         'collaborative': x['collaborative'],
                         }
                playlists = playlists.append(pd.DataFrame([items]))
        playlists.reset_index(drop=True, inplace=True)
        return playlists

# %%
def recursive_skim(obj, d={}, f=0):
    for x in obj.keys():
        level = obj[x]
        print(f, '\t'*f, '*', x, type(level), '[0] {}'.format(type(level[0] if type(level) == list else level)) if type(level) == list else '')
        if type(level) in (list, dict):
            level_next = level[0] if type(level) == list else level
            if type(level_next) in (list, dict):
                recursive_skim(level_next, d, f+1)

# %%
Cassie = Sameify(user_ids['Cassie'])

# %%
Art = Sameify('artlolos1')
# Out:
#             User authentication requires interaction with your
#             web browser. Once you enter your credentials and
#             give authorization, you will be redirected to
#             a url.  Paste that url you were directed to to
#             complete the authorization.
#
#
# Opened https://accounts.spotify.com/authorize?client_id=a7a7510a67034ce28856364ce96c5504&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8889%2F&scope=playlist-modify-public+user-library-read+user-read-recently-played in your browser
#
#
# Enter the URL you were redirected to: http://localhost:8889/tree?code=AQDcgf1arb5y2h8ehaccpC5WabxdaVVQ90lDXTJucW-Dk7-T-SCTlHs4KNa1HAAR5T-1sfbb8zm6JE_oM-4gYweq_5rcg5hjJTLNDXy7J9qOlwqXlNpym0OdcrnyoHpw8P5X9WfxCN-SxtxLkjDr7nNZSxgM6LS6YPBBRib2jLWKMBYDfnYr1xzRw0jOCNLYg1FhQAP_MJkOCFVeP_f5Sc2d791sKoD5OInojQcUUyGaKzW2bTudbhEGCOWRJQiQ7T6Mz-D9kKE7EUCQ_E4fJlXB

# %%
Alex = Sameify(user_ids['Alex'])

# %%
Caity = Sameify(user_ids['Caity'])
Ben = Sameify(user_ids['Ben'])
Jason = Sameify(user_ids['Jason'])

# %% [markdown]
# # How to see playlists

# %%
Cassie.get_all_playlists()

# %%
playlists = Cassie.get_all_playlists()
playlists

# %% [markdown]
# # How to see songs in a playlist

# %%
a_tracks = Alex.playlist_tracks(Alex.get_playlist_id('Liked from Radio'))
a_tracks

# %%
a_tracks.iloc[0]

# %% [markdown]
# # See original depth tree of playlist info

# %%
x = Alex.sp.user_playlist(Alex.id, Alex.get_playlist_id('Liked from Radio'))
recursive_skim(x)

# %% [markdown]
# # See new depth tree of playlist info
# I pulled out the values I felt were most useful, see above in the class definition

# %%
y = Alex.playlist_tracks(Alex.get_playlist_id('Liked from Radio'))
recursive_skim(y)

# %% [markdown]
# # Visualize a playlist

# %%
# simplify and melt playlist
def melt_df(df):
    new_df = df[['playlist_name', 'track_id', 'acousticness', 'danceability', 'energy', 'liveness', 'valence', 'speechiness']]
    return new_df.melt(id_vars=['playlist_name', 'track_id'])

# %%
# melt playlist
alex_playlist_melt = melt_df(a_tracks)
alex_playlist_melt

# %%
# display musical information
fig, ax = plt.subplots(figsize=(20,15))
ax = sns.boxplot(x='variable', y='value', hue='playlist_name', data=alex_playlist_melt, palette='Accent')

# %% [markdown]
# # Compare playlists

# %%
# pull french playlist from cassie
c_tracks = Cassie.playlist_tracks(Cassie.get_playlist_id('Inside my head.'))

# melt playlist
cassie_playlist_melt = melt_df(c_tracks)
cassie_playlist_melt

# %%
melted = alex_playlist_melt.append(cassie_playlist_melt)

# display musical information
fig, ax = plt.subplots(figsize=(20,15))
ax = sns.boxplot(x='variable', y='value', hue='playlist_name', data=melted, palette='Accent')

# %% [markdown]
# # Play around with data

# %%
len(Cassie.get_all_playlists())
#162

# %%
p_id = Cassie.get_playlist_id('Miki Ratsula')

# %%
Cassie.sp.

# %%
Cassie.sp.user_playlist_add_tracks(user = Cassie, 
                                   playlist_id = p_id,
                                   tracks = ['6i4m9NMsIenenO2djGUTpe', '2OJFqxSN8Qk37TpzZy2UZz'],
                                   position = [1,3])

# %%
ts = ['6i4m9NMsIenenO2djGUTpe', '2OJFqxSN8Qk37TpzZy2UZz']
ps = [1,3]

# %%
p_id = Alex.get_playlist_id('Plane')

# %%
xx = Cassie.sp.current_user_recently_played()

# %%
xx

# %%
xx['items'][0]['track']['type']

# %%
xx['next']

# %%
xx.keys()

# %%
https://api.spotify.com/v1/me/player/recently-played?before=1581012036871&limit=50'

# %%
xx['cursors']

# %%
[x['track']['name'] for x in xx['items']]

# %%
p_id = Cassie.get_playlist_id('Miki Ratsula')

# %%
Cassie.sp.search()

# %%
Cassie.sp.playlist_tracks(p_id)['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
pd.to_datetime(Cassie.sp.playlist_tracks(p_id)['items'][0]['track']['album']['release_date']).year
# Out:
# 2017

# %%
Cassie.get_playlist

# %%
a_tracks = Alex.playlist_tracks(Alex.get_playlist_id('Liked from Radio'))

# %%
a_tracks = a_tracks[['track_name', 'track_id', 'track_artist_id', 'track_artist']].copy()

# %%
Cassie.get_all_playlists()
# Out:
#                                          playlist_name  \
# 0                                          January '20
# 1                                         Miki Ratsula
# 2                                             Cleaning
# 3                                    Perfect Harmonies
# 4                                      Discover Weekly
# 5                                        Release Radar
# 6                                                  New
# 7                                          Alarm songs
# 8                                                    0
# 9                                                    1
# 10                                    Morning Playlist
# 11                                        December '19
# 12                                        November '19
# 13                                         October '19
# 14                                       September '19
# 15                                          August '19
# 16                                            July '19
# 17                                            June '19
# 18                                             May '19
# 19                                           April '19
# 20                                           March '19
# 21                                        February '19
# 22                                         January '19
# 23                                        December '18
# 24                                        November '18
# 25                                         October '18
# 26                                       September '18
# 27                                          August '18
# 28                                            July '18
# 29                                          SoundHound
# 30                               Release Radar Archive
# 31                             Discover Weekly Archive
# 32                                       Test Playlist
# 33                                Inspired By Warriors
# 34                                      Breathe me in.
# 35                                     Inside my head.
# 36                                      Mind on Repeat
# 37                                     Past Obsessions
# 38                                      Teenage Cassie
# 39                                         Summer 2017
# 40                                Zero’s Pet Playlist
# 41                                            Hamilton
# 42                                   Beats to think to
# 43                                               Sleep
# 44           **DEEP FOCUS** Orchestral Post-Minimalism
# 45                                          Deep Focus
# 46                                  Cinematic Chillout
# 47                                 Cinematic Classical
# 48                                        Soundwave CD
# 49                                         האהובים עלי
# 50                                    Morning Acoustic
# 51                                          Chill Lah!
# 52                                 PTX Christmas Songs
# 53                                  Acapella Christmas
# 54                                         Happy Beats
# 55                                      It's ALT Good!
# 56                                        Mood Booster
# 57                                        Hot Rhythmic
# 58                                   Best of - Remixes
# 59                                        Mega Hit Mix
# 60                                             Workout
# 61                                    Headphone Tester
# 62                                                Rawr
# 63                                      Skip skip skip
# 64                            I Wish I Knew These Then
# 65                                  FORGOT THE NAME AH
# 66                                 Your Top Songs 2018
# 67                                                 🤘🏻🐰
# 68                                   Riffs of Paradise
# 69                                      Acapella Feels
# 70                                  Discovered & Loved
# 71                                                Band
# 72                                    High School Band
# 73                                           Completed
# 74                                         In Progress
# 75                                          On Backlog
# 76                                               Piano
# 77                                             Harmony
# 78                              I'm in a good mood. <3
# 79                                                Nom.
# 80                                            I'm Sad.
# 81                                Anxiety, click here.
# 82                                      New One! AGAIN
# 83                             If I Ever Did Burlesque
# 84                                           s0ngz4ddr
# 85                                             New Run
# 86                          Crochelliptical Experience
# 87                                         New Workout
# 88                                         Morning Run
# 89                                         New Workout
# 90                                            Running!
# 91                                         Poi/hooping
# 92                                < 80 BPM (clem leek)
# 93                             80-99 BPM (flute fruit)
# 94                                 100-119 BPM (intro)
# 95                                  120-139 BPM (sail)
# 96                         140-159 BPM (kingston town)
# 97                    160-179 BPM (and the day turned)
# 98                              > 180 BPM (linguistic)
# 99                                      YES to Hooping
# 100                        30 Min Fun- Fitness Hooping
# 101                            Ideas for Hooping Songs
# 102                            25 min Focus Session :)
# 103                                  Guided Meditation
# 104  Brainwave Binaural Systems — Happy States of Mind
# 105                                     Songs Saved v1
# 106                                     Songs Saved v2
# 107                                   A girl long ago.
# 108                                          Streaming
# 109                                  #cantstopwontstop
# 110                                       Because yes.
# 111                                     Because maybe.
# 112                           Old Discovered and Loved
# 113                                  Current Favorites
# 114                                             For CD
# 115                                            Indian!
# 116                                              日本の音楽
# 117                                     Linguistic Mix
# 118                                          Sign Away
# 119                               Mes Favoris Français
# 120                                        Hebrew, Unf
# 121                                         Español :)
# 122                                  Awesome Discovery
# 123                                      All the Songs
# 124                                             Covers
# 125                                       Flashbackkkk
# 126                                          "Starred"
# 127                                      For Aunt Roni
# 128                                    Cassie again ;)
# 129                                From A Man Long Ago
# 130                                         Sam4school
# 131                                          Beautiful
# 132                                            Driving
# 133                                    Getting pumped!
# 134                       Stealing From Your Playlists
# 135                                   Best of the Best
# 136                                        Good Places
# 137                               Drag Show Potentials
# 138                         TNG, you've stuck with me.
# 139                                   1, 2, 3, slow :)
# 140                                     1, 2, 3, go :)
# 141                                  Acoustic Cuteness
# 142                                           Acapella
# 143                                      Radio Country
# 144               When Country Gets Stuck In Your Head
# 145                                             Frozen
# 146                                      The Music Man
# 147                                              ARORA
# 148                                        Cady Groves
# 149                                       Cody Simpson
# 150                                         Ed Sheeran
# 151      Hollywood Undead - Notes From the Underground
# 152                                        Jon Bellion
# 153                             Joshua Radin Favorites
# 154                               Jonas B. Ingebretsen
# 155                                             Lecrae
# 37   1sKQJ9Eh4gulXP4dU0DlvI            Cassie Beth                 1242091675
# 38   6Jz70BHkApBxmXdaN0o0zP            Cassie Beth                 1242091675
# 39   71rzcr9mf3hBTqKa3c75vT            Cassie Beth                 1242091675
# 40   5MJFQfj8S9e54F63YiuNBx            Cassie Beth                 1242091675
# 41   1DuTdfXK4viAVtFbKqmC9V            Cassie Beth                 1242091675
# 42   37i9dQZF1DXa2SPUyWl8Y5                Spotify                    spotify
# 43   37i9dQZF1DWZd79rJ6a7lp                Spotify                    spotify
# 44   0MNuR6ksKbts4NOGOo18bU                  m_olv                      m_olv
# 45   37i9dQZF1DWZeKCadgRdKQ                Spotify                    spotify
# 46   37i9dQZF1DWVFJtzvDHN4L                Spotify                    spotify
# 47   7FuxvQt3lZA6IbIByvrejj  James Ferguson-Hannah                 1141241103
# 48   1OnBpOEq4G0irR6GHLMyee            Cassie Beth                 1242091675
# 49   2mhVQi9TBDg6650iX8tkzx            Cassie Beth                 1242091675
# 50   37i9dQZF1DXdd3gw5QVjt9                Spotify                    spotify
# 51   37i9dQZF1DX2QWdoTGeQgx                Spotify                    spotify
# 52   7rRn7cQsMDPbJUlJgY8bOW             1254380505                 1254380505
# 53   6G9nI7FGoUNB2GupTwJwvB      Adam B Williamson                sigmachirev
# 54   37i9dQZF1DWSf2RDTDayIx                Spotify                    spotify
# 55   37i9dQZF1DX2SK4ytI2KAZ                Spotify                    spotify
# 56   37i9dQZF1DX3rxVfibe1L0                Spotify                    spotify
# 57   37i9dQZF1DWYs83FtTMQFw                Spotify                    spotify
# 58   18r4ikQ9QIEadE297sYmaL              121748172                  121748172
# 59   37i9dQZF1DXbYM3nMM0oPk                Spotify                    spotify
# 60   37i9dQZF1DX70RN3TfWWJh                Spotify                    spotify
# 61   05gOgbTXUV9SAkNXaSEnIe           andrebehrens               andrebehrens
# 62   5kBLud9twrIvcp3c9SOOwv            Cassie Beth                 1242091675
# 63   3V5OvrzC1ZFuUAkAMWj5rG            Cassie Beth                 1242091675
# 64   6p8y7nLj82MSReFuPcScIy            Cassie Beth                 1242091675
# 65   6NP9vcDFTL7RVK8TpikVvW            Cassie Beth                 1242091675
# 66   37i9dQZF1EjlZ3B5Qfn8ny                Spotify                    spotify
# 67   6qOe8lksjZeaIPoGWsoC1r        beccalynnkruger            beccalynnkruger
# 68   16VCVfa7Lvo5clo54tkobE         Matt O'Connell  21puvemz2tdntb3qzyp2kmxhq
# 69   78SUfHvHMkhQtGcY50Zrt5            Cassie Beth                 1242091675
# 70   7MpbX5HSu7FnsK8E4ZcGzD            Cassie Beth                 1242091675
# 71   0XJoZiyk5enQOKP17Sp9Kh            Cassie Beth                 1242091675
# 72   2xxqGjadUK2bR3vQVRbPx9            Cassie Beth                 1242091675
# 73   3sUARdIqaInRczNmgp5RmO            Cassie Beth                 1242091675
# 74   3A0c1i4lrjIQgfkx2OoPcC            Cassie Beth                 1242091675
# 75   2CgjEhlcq3INBKZq28gNls            Cassie Beth                 1242091675
# 76   7H1VZE4FC5LUS23NhGxK77            Cassie Beth                 1242091675
# 77   002LUVqRUTJStnXmarggHv            Cassie Beth                 1242091675
# 157  7lc39PsuSRnIM2gm3dC7kI            Cassie Beth                 1242091675
# 158  5pohbCFcKRv2YAN2VAh8SH            Cassie Beth                 1242091675
# 159  1OcMvjkLSP97NEnpx0yrS3            Cassie Beth                 1242091675
# 160  6E0ComdfciqmX53MbqukS9            Cassie Beth                 1242091675
# 161  35gsTDxD8gyX1hL2DPvQe8            Cassie Beth                 1242091675
# 162  0UCb3kSPZXqsptKPTg1SpO            Cassie Beth                 1242091675
#
#      num_tracks  collaborative
# 0             7          False
# 1            24          False
# 2             2          False
# 3             8          False
# 4            30          False
# 5            30          False
# 6             1          False
# 7             2          False
# 8             1          False
# 9             4          False
# 10            4          False
# 11            6          False
# 12            5          False
# 13            7          False
# 14            5          False
# 15           16          False
# 16           11          False
# 17           12          False
# 18            5          False
# 19            9          False
# 20           20          False
# 21           30          False
# 22           22          False
# 23           21          False
# 24           12          False
# 25           13          False
# 26            8          False
# 27           11          False
# 28            9          False
# 29           12          False
# 30         3126          False
# 31         2709          False
# 32            2          False
# 33           33          False
# 34           34          False
# 35           58          False
# 36           14          False
# 37            2          False
# 38           42          False
# 39           21          False
# 40           30          False
# 41           46          False
# 42           80          False
# 43          275          False
# 44           36          False
# 45          184          False
# 46           50          False
# 47          312          False
# 48            7          False
# 49           24          False
# 50           75          False
# 51           88          False
# 52           23          False
# 53           63          False
# 54           80          False
# 55          100          False
# 56           75          False
# 57           50          False
# 58          285          False
# 59           75          False
# 60           60          False
# 61          746          False
# 62            1          False
# 63            4          False
# 64            3          False
# 65            1          False
# 66          100          False
# 67           88          False
# 68           15          False
# 69            6          False
# 70          149          False
# 71            7          False
# 72           29          False
# 73            3          False
# 74            3          False
# 75           19          False
# 76            4          False
# 77           10          False
# 78            3          False
# 79            3          False
# 80           12          False
# 81            2          False
# 82           13          False
# 83           11          False
# 84            6          False
# 85            8          False
# 86           13          False
# 87           10          False
# 88           30          False
# 89            7          False
# 90           10          False
# 91          385          False
# 92            1          False
# 93            4          False
# 94            3          False
# 95            3          False
# 96            3          False
# 97            2          False
# 98            1          False
# 99            4          False
# 100          11          False
# 101           8          False
# 102           6          False
# 103           8          False
# 104           3          False
# 105         113          False
# 106          53          False
# 107          10          False
# 108          36          False
# 109          30          False
# 110          26          False
# 111          10          False
# 112          58          False
# 113          18          False
# 114          13          False
# 115           1          False
# 116           6          False
# 117          17          False
# 118           5          False
# 119          15          False
# 120          17          False
# 121           7          False
# 122          31          False
# 123          16          False
# 124          25          False
# 125          87          False
# 126          53          False
# 127           7          False
# 128          42          False
# 129          35          False
# 130          83          False
# 131          12          False
# 132          72          False
# 133          13          False
# 134          22          False
# 135          29          False
# 136          75          False
# 137          10          False
# 138           7          False
# 139          41          False
# 140          38          False
# 141          23          False
# 142          13          False
# 143          20          False
# 144          14          False
# 145          59          False
# 146          18          False
# 147          17          False
# 148          12          False
# 149          29          False
# 150          36          False
# 151          32          False
# 152          24          False
# 153          11          False
# 154          23          False
# 155          15          False
# 156          25          False
# 157          49          False
# 158          73          False
# 159          51          False
# 160          51          False
# 161          39          False
# 162           4          False

# %%
a_tracks['genre'] = Alex.playlist_tracks(Alex.get_playlist_id('Liked from Radio'))['track_artist_id'].apply(lambda x: Alex.sp.artist(x)['genres'])

# %%
[print(Alex.sp.artist(x)['genres']) for x in Cassie.playlist_tracks(Cassie.get_playlist_id('Inside my head.'))['track_artist_id']]
# Out:
# ['candy pop', 'neo mellow', 'norwegian pop', 'norwegian singer-songwriter']
# ['alternative rock', 'baroque pop', 'canadian indie', 'chamber pop', 'indie folk', 'indie pop', 'indie rock', 'modern folk rock', 'modern rock', 'stomp and holler']
# ['marching band', 'wind ensemble']
# ['american contemporary classical', 'concert band']
# ['pop', 'pop rap']
# ['alternative pop rock', 'neon pop punk', 'pop emo', 'pop punk', 'texas pop punk']
# []
# ['a cappella']
# []
# ['a cappella']
# ['modern ska punk', 'pop punk', 'punk', 'ska', 'ska punk', 'skate punk']
# ['indiecoustica', 'stomp and holler']
# ['a cappella']
# ['acoustic pop', 'neo mellow', 'pop', 'pop rock', 'viral pop']
# []
# ['comic', 'geek rock', 'permanent wave', 'zolo']
# ['candy pop', 'neo mellow', 'norwegian pop', 'norwegian singer-songwriter']
# ['metropopolis', 'modern rock', 'pop', 'pop rock', 'rock', 'tropical house']
# []
# ['contemporary country', 'country', 'country road', 'modern country rock']
# ['piano rock']
# ['acoustic pop', 'ectofolk', 'indiecoustica', 'lilith', 'neo mellow', 'pop', 'pop rock']
# ['ectofolk', 'lilith', 'melancholia', 'piano rock']
# ['british soundtrack', 'epicore', 'scorecore', 'soundtrack', 'video game music']
# ['alternative dance', 'art pop', 'chamber psych', 'dance pop', 'dance-punk', 'electronica', 'electropop', 'indietronica', 'neo-synthpop', 'new rave', 'trip hop']
# ['modern mod']
# ['chamber pop', 'indie pop', 'lilith', 'piano rock', 'pop rock']
# ['piano rock']
# ['boston rock', 'indie pop', 'modern rock', 'neo mellow', 'pop rock']
# ['canadian rock', 'pop rock']
# ['pop', 'post-teen pop', 'viral pop']
# ['pop', 'pop rock', 'post-teen pop']
# ['acoustic pop', 'indie folk', 'indiecoustica', 'neo mellow', 'pop rock', 'viral pop']
# ['channel pop', 'viral pop']
# []
# ['alternative rock', 'pop rock', 'post-grunge', 'rock']
# ['candy pop', 'neo mellow', 'norwegian pop', 'norwegian singer-songwriter']
# ['dreamo', 'emo', 'neon pop punk', 'philly indie', 'pop emo', 'pop punk', 'screamo']
# ['canadian ccm', 'christian alternative rock', 'christian music', 'christian punk', 'christian rock', 'indiecoustica', 'neo mellow', 'pop punk', 'pop rock']
# ['bow pop', 'emo', 'pop punk', 'pop rock', 'post-grunge', 'socal pop punk']
# ['emo', 'metalcore', 'pop punk', 'post-hardcore', 'screamo']
# ['acoustic pop', 'indie folk', 'indiecoustica', 'neo mellow', 'pop rock', 'viral pop']
# ['modern rock', 'pop punk', 'post-teen pop', 'rock']
# ['alternative pop rock', 'neon pop punk']
# ['alternative metal', 'metalcore', 'pixie', 'pop punk', 'screamo']
# ['otacore', 'post-teen pop']
# ['alternative metal', 'christian alternative rock', 'christian rock', 'nu metal', 'pop emo', 'post-grunge']
# ['slam poetry']
# ['birmingham hip hop', 'grime', 'modern rock', 'uk garage']
# ['antiviral pop', 'comic']
# ['scottish indie']
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rap rock']
# ['alternative metal', 'nu metal', 'post-grunge', 'rap metal', 'rap rock']
# ['eurobeat', 'j-idol', 'j-pop', 'japanese r&b']
# []
# ['a cappella', 'college a cappella']
# ['easycore', 'emo', 'pop punk', 'post-grunge', 'punk', 'skate punk']
# ['indie rockism']
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
a_genres

# %%
recursive_skim(Cassie.sp.playlist_tracks(p_id))
# Out:
# 0  * href <class 'str'>
# 0  * items <class 'list'> [0] <class 'dict'>
# 1 	 * added_at <class 'str'>
# 1 	 * added_by <class 'dict'>
# 2 		 * external_urls <class 'dict'>
# 3 			 * spotify <class 'str'>
# 2 		 * href <class 'str'>
# 2 		 * id <class 'str'>
# 2 		 * type <class 'str'>
# 2 		 * uri <class 'str'>
# 1 	 * is_local <class 'bool'>
# 1 	 * primary_color <class 'NoneType'>
# 1 	 * track <class 'dict'>
# 2 		 * album <class 'dict'>
# 3 			 * album_type <class 'str'>
# 3 			 * artists <class 'list'> [0] <class 'dict'>
# 4 				 * external_urls <class 'dict'>
# 5 					 * spotify <class 'str'>
# 4 				 * href <class 'str'>
# 4 				 * id <class 'str'>
# 4 				 * name <class 'str'>
# 4 				 * type <class 'str'>
# 4 				 * uri <class 'str'>
# 3 			 * available_markets <class 'list'> [0] <class 'str'>
# 3 			 * external_urls <class 'dict'>
# 4 				 * spotify <class 'str'>
# 3 			 * href <class 'str'>
# 3 			 * id <class 'str'>
# 3 			 * images <class 'list'> [0] <class 'dict'>
# 4 				 * height <class 'int'>
# 4 				 * url <class 'str'>
# 4 				 * width <class 'int'>
# 3 			 * name <class 'str'>
# 3 			 * release_date <class 'str'>
# 3 			 * release_date_precision <class 'str'>
# 3 			 * total_tracks <class 'int'>
# 3 			 * type <class 'str'>
# 3 			 * uri <class 'str'>
# 2 		 * artists <class 'list'> [0] <class 'dict'>
# 3 			 * external_urls <class 'dict'>
# 4 				 * spotify <class 'str'>
# 3 			 * href <class 'str'>
# 3 			 * id <class 'str'>
# 3 			 * name <class 'str'>
# 3 			 * type <class 'str'>
# 3 			 * uri <class 'str'>
# 2 		 * available_markets <class 'list'> [0] <class 'str'>
# 2 		 * disc_number <class 'int'>
# 2 		 * duration_ms <class 'int'>
# 2 		 * episode <class 'bool'>
# 2 		 * explicit <class 'bool'>
# 2 		 * external_ids <class 'dict'>
# 3 			 * isrc <class 'str'>
# 2 		 * external_urls <class 'dict'>
# 3 			 * spotify <class 'str'>
# 2 		 * href <class 'str'>
# 2 		 * id <class 'str'>
# 2 		 * is_local <class 'bool'>
# 2 		 * name <class 'str'>
# 2 		 * popularity <class 'int'>
# 2 		 * preview_url <class 'str'>
# 2 		 * track <class 'bool'>
# 2 		 * track_number <class 'int'>
# 2 		 * type <class 'str'>
# 2 		 * uri <class 'str'>
# 1 	 * video_thumbnail <class 'dict'>
# 2 		 * url <class 'NoneType'>
# 0  * limit <class 'int'>
# 0  * next <class 'NoneType'>
# 0  * offset <class 'int'>
# 0  * previous <class 'NoneType'>
# 0  * total <class 'int'>
